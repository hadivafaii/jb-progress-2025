# %% [markdown]
# # (10) grad: (T, beta) = (32, 32.0)
#
# project = ```iP-VAE```, host = ```yoru```, device = ```cuda:1```
#
# **Motivation**: <br>
#
# Added a single global multiplicative contrast term to ```self.phi```: bad idea

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_IterativeVAE'))
# from analysis.eval import sparse_score
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
from figures.analysis import plot_convergence
from figures.imgs import plot_weights


device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: yoru

# %% [markdown]
# ## Trainer

# %%
model_type = 'poisson'

cfg_vae, cfg_tr = default_configs('vH16', model_type, 'grad|lin')
cfg_vae['seq_len'] = 32 # 16
cfg_vae['n_iters'] = 1

cfg_vae['track_stats'] = False

cfg_vae['beta_inner'] = 1.0
cfg_tr['kl_beta'] = 32.0 # 20.0

print(f"VAE:\n{cfg_vae}\n\nTrainer:\n{cfg_tr}")
# Out:
# VAE:
# {'dataset': 'vH16', 'n_latents': 512, 'clamp_prior': -4, 'clamp_du': 10.0, 'clamp_u': 8.0, 'inf_type': 'grad',
# 'dec_type': 'lin', 'init_dist': 'normal', 'init_scale': 0.0001, 'seq_len': 32, 'n_iters': 1, 'track_stats': False,
# 'beta_inner': 1.0}
#
# Trainer:
# {'batch_size': 200, 'epochs': 300, 'optimizer_kws': {'weight_decay': 0.0}, 'grad_clip': 200, 'kl_beta': 32.0}

# %%
mod = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(mod, ConfigTrain(**cfg_tr), device=device)

mod.print()
print(f"{mod.cfg.name()}\n{tr.cfg.name()}_({mod.timestamp})\n")
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  132.3 K   |
# |     ———     |    ———     |
# |    layer    |  132.3 K   |
# +-------------+------------+
# poisson_vH16_t-32_z-[512]_<grad|lin>
# b200-ep300-lr(0.002)_beta(32:0x0.1)_temp(0.05:lin-0.5)_gr(200)_(2025_02_11,17:12)

# %%
print(tr.model.layer)
# Out:
# PoissonLayer(input_dim=256,latent_dim=512, beta_inner=1, temp=1)

# %%
tr.model.layer.log_bias.shape, tr.model.layer.log_lr.exp()
# Out:
# (torch.Size([1, 512]), tensor([1.], device='cuda:0', grad_fn=<ExpBackward0>))

# %%
tr.model.layer.update_n_exp(11.0)
tr.model.layer.n_exp
# Out:
# tensor([30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30,
#         30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30],
#        device='cuda:0', dtype=torch.int32)

# %%
# cm = ''
# tr.train(fit_name=f"{cm}_{tr.cfg.name()}")

tr.train()
# Out:
# epoch # 300, avg loss: 167.408153: 100%|████| 300/300 [7:51:43<00:00, 94.35s/it]

# %%
### Was: (16, 20.0)
# Out:
# epoch # 300, avg loss: 223.946191: 100%|████| 300/300 [2:52:50<00:00, 34.57s/it]

# %%
print(tr.model.layer.n_exp)
# Out:
# tensor([ 35,  47,  63,  82, 102, 119, 132, 140, 143, 146, 147, 148, 148, 148,
#         148, 148, 148, 148, 148, 148, 147, 147, 148, 147, 147, 147, 147, 147,
#         147, 147, 147, 146], device='cuda:0', dtype=torch.int32)

# %%
u0 = tonp(tr.model.layer.u_init.squeeze())
tr.model.show(order=np.argsort(u0));

# %%
### Was: (T, beta) = (16, 20.0)

# %%
### Was: (T, beta) = (8, 12.0)

# %%
fig, ax = create_figure()

sns.histplot(tonp(tr.model.layer.log_bias.squeeze().exp()), label='bias', stat='percent',  ax=ax)
ax.legend()
plt.show()

# %%
### Was: (T, beta) = (16, 20.0)

# %%
log_scale = tonp(tr.model.layer.log_scale.squeeze())
histplot(np.exp(log_scale) ** 2, label='dec var')
plt.legend()
plt.show()

# %%
var = np.exp(log_scale) ** 2
var = var.reshape(16, 16)

var_data = tr.dl_vld.dataset.tensors[0].var(dim=0).squeeze()

fig, ax =  create_figure()
imshow(var, cmap='Greys_r')
plt.colorbar()
plt.show()

fig, ax =  create_figure()
imshow(var_data, cmap='Greys_r')
plt.colorbar()
plt.show()

# %%
# %%time

kws = dict(
    seq_total=10000,
    seq_batch_sz=1000,
    n_data_batches=10,
)
results = tr.analysis('vld', **kws)
_ = plot_convergence(results, color='k')
# Out:
# 100%|█████████████████████████████████| 10/10 [03:04<00:00, 18.45s/it]
# CPU times: user 4min 5s, sys: 5.07 s, total: 4min 10s
# Wall time: 4min 10s

# %%
### Was: (T, beta) = (16, 20.0)
# Out:
# 100%|█████████████████████████████████| 10/10 [03:33<00:00, 21.31s/it]

# %% [markdown]
# ## output

# %%
# %%time

output = tr.model.xtract_ftr(
    feeder=tr.get_feeder(),
    seq=range(1000),
    return_extras=True,
).stack()

print(list(output))
# Out:
# ['loss_kl', 'loss_recon', 'posterior', 'du', 'u', 'v', 'recon', 'samples', 'conditional', 'mse', 'r2']
# CPU times: user 1.7 s, sys: 2.92 ms, total: 1.7 s
# Wall time: 1.7 s

# %%
u_norm = tonp(torch.linalg.norm(output['u'], axis=-1).mean(0))
v_norm = tonp(torch.linalg.norm(output['v'], axis=-1).mean(0))
r_norm = tonp(torch.linalg.norm(torch.exp(output['u']), axis=-1).mean(0))

# a_norm = torch.linalg.norm(output['a'], axis=-1)

# %%
fig, axes = create_figure(1, 3)
axes[0].plot(u_norm, label='u', color='r')
axes[1].plot(v_norm, label='v', color='k')
axes[2].plot(r_norm, label='r')

add_legend(axes)
plt.show()

# %%
### Was: (T, beta) = (16, 20.0)

# %%
feeder = tr.get_feeder()

locs = torch.stack([
    p.loc for p in
    output['conditional'].values()
], dim=1)
mse = (locs - feeder[0].unsqueeze(1)).pow(2).sum(-1)
plot(mse.mean(0))
plt.yscale('log')
plt.show()

mse.mean(0)[-5:]
# Out:
# tensor([13.9591, 13.9971, 13.9226, 13.9535, 13.7257], device='cuda:0')

# %%
num = 20
n_timepoints = 40

x2p = tonp(locs)[:num]
x2p = x2p[:, :n_timepoints]

true = tonp(feeder[0][:num].unsqueeze(1))
x2p = np.concatenate([x2p, np_nans(true.shape), true], axis=1)

x2p = x2p.reshape(tr.model.cfg.shape)
x2p = x2p.squeeze()

_ = plot_weights(x2p, nrows=num)

# %%
x2p = tonp(output['recon'])[:num]
x2p = x2p[:, :n_timepoints]

true = tonp(feeder[0][:num].unsqueeze(1))
x2p = np.concatenate([x2p, np_nans(true.shape), true], axis=1)

x2p = x2p.reshape(tr.model.cfg.shape)
x2p = x2p.squeeze()

_ = plot_weights(x2p, nrows=num)
