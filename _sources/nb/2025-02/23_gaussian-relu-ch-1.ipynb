# %% [markdown]
# # (23) gaussian-relu: (16, 16.0)
#
# project = ```iP-VAE```, host = ```chewie```, device = ```cuda:1```
#
# **Motivation**: <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_IterativeVAE'))
from figures.analysis import plot_convergence
from figures.imgs import plot_weights
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 1
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:1  ———  host: chewie

# %% [markdown]
# ## Trainer

# %%
model_type = 'gaussian'
cfg_vae, cfg_tr = default_configs(model_type, 'vH16', 'grad|lin')

cfg_vae['n_latents'] = 512
cfg_vae['latent_act'] = 'relu'

cfg_vae['clamp_u'] = 4.0
cfg_vae['clamp_du'] = 4.0

cfg_vae['seq_len'] = 32
cfg_tr['kl_beta'] = 32.0
cfg_tr['kl_anneal_portion'] = 0.3

cfg_tr['lr'] = 1e-4

cfg_tr['dataset_kws'] = {
    'file_name': 'patches.npy',
    'shift_rescale': True,
}

cfg_vae['track_stats'] = True

# %%
tr = Trainer(
    model=MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae)),
    cfg=ConfigTrain(**cfg_tr),
    device=device,
)

tr.model.print()
print(f"{tr.model.cfg.name()}\n{tr.cfg.name()}_({tr.model.timestamp})\n")
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IGVAE    |  132.9 K   |
# |     ———     |    ———     |
# |    layer    |  132.9 K   |
# +-------------+------------+
# gaussian_relu_vH16_t-32_z-[512]_cl-4,4_<grad|lin>
# b200-ep300-lr(0.0001)_beta(32:0.3)_gr(500)_(2025_02_26,09:15)

# %%
print(tr.model.layer)
# print(tr.model.layer.n_exp)
# Out:
# GaussianLayer(input_dim=256, latent_dim=512, temperature=1, beta_inner=1, eps=1)

# %%
tuple(llr.exp() for llr in tr.model.layer.log_lr)
# Out:
# (tensor([1.], device='cuda:1', grad_fn=<ExpBackward0>),
#  tensor([1.], device='cuda:1', grad_fn=<ExpBackward0>))

# %%
cm = f"non-whitened"
tr.train(fit_name=f"{cm}_{tr.cfg.name()}")

# tr.train()

# %%
tuple(llr.exp() for llr in tr.model.layer.log_lr)
# Out:
# (tensor([0.7819], device='cuda:1', grad_fn=<ExpBackward0>),
#  tensor([0.3388], device='cuda:1', grad_fn=<ExpBackward0>))

# %%
u0 = tonp(tr.model.layer.u_init[0].squeeze())
u1 = tonp(tr.model.layer.u_init[1].squeeze())
tr.model.show(order=np.argsort(u1), nrows=8);

# %%
w = tr.model.layer.get_weight().data
w = tonp(w.T.reshape(-1, 16, 16))
w.shape
# Out:
# (256, 16, 16)

# %%
histplot(w.ravel())
plt.show()

# %%
w = tonp(tr.model.layer.get_weight())
w = w.T[np.argsort(u1)]

x2p = w[111].reshape(16, 16)

fig, axes = create_figure(1, 2, width_ratios=[1, 1.5])
axes[0].imshow(x2p, cmap='Greys')
axes[1].plot(x2p[3:11].T)
axes[1].axhline(0, color='dimgrey', ls='--', zorder=0)
plt.show()

# %%
histplot(u1, color='dimgrey')
plt.show()

# %%
fig, ax = create_figure()

sns.histplot(tonp(tr.model.layer.log_bias.squeeze().exp()), label='bias', stat='percent',  ax=ax)
ax.legend()
plt.show()

# %%
log_scale = tonp(tr.model.layer.get_dec_log_sigma().squeeze())
histplot(np.exp(log_scale) ** 2, label='dec var')
plt.legend()
plt.show()

# %%
var = np.exp(log_scale) ** 2
var = var.reshape(16, 16)

var_data = tr.dl_vld.dataset.tensors[0].var(dim=0).squeeze()

fig, ax =  create_figure()
imshow(var, cmap='Greys_r')
plt.colorbar()
plt.show()

fig, ax =  create_figure()
imshow(var_data, cmap='Greys_r')
plt.colorbar()
plt.show()

# %%
# %%time

kws = dict(
    seq_total=10000,
    seq_batch_sz=1000,
    n_data_batches=2,
)
results = tr.analysis('vld', **kws)
_ = plot_convergence(results, color='k')
# Out:
#   0%|                                           | 0/2 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# File <timed exec>:6
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_IterativeVAE/main/train.py:707, in Trainer.analysis(self, dl, seq_total, seq_batch_sz, active, n_data_batches, return_recon, avg_samples, verbose, **kwargs)
#     705 kwargs['seq'] = range(start, end)
#     706 # (2) fwd pass
# --> 707 output = model.xtract_ftr(feeder, **kwargs)
#     708 # (3) save
#     709 if end == seq_total:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_IterativeVAE/main/model.py:58, in _IterativeVAE.xtract_ftr(self, feeder, **kwargs)
#      56 temp = self.cfg.validation_temp
#      57 kwargs.setdefault('temp', temp)
# ---> 58 return self.forward(feeder, **kwargs)
#
# File ~/Dropbox/git/_IterativeVAE/main/model.py:39, in _IterativeVAE.forward(self, feeder, temp, seq, return_extras, override_x)
#      37 	x = feeder[t]  # actual data
#      38 # (1) bottom-up pass
# ---> 39 _ = self.layer(x, temp=temp)
#      40 # (2) generate & update:
#      41 self.update_generation_state(temp=temp)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:34, in _StochasticLayer.forward(self, x, temp)
#      32 	return self.infer(x)
#      33 with self.temporary_temperature(temp):
# ---> 34 	return self.infer(x)
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:38, in _StochasticLayer.infer(self, x)
#      36 def infer(self, x):
#      37 	if self._cfg.inf_type == 'grad':
# ---> 38 		return self.infer_grad(x)
#      39 	elif self._cfg.inf_type == 'leapfrog':
#      40 		return self.infer_leapfrog(x)
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:50, in _StochasticLayer.infer_grad(self, x)
#      48 for n in range(self._cfg.n_iters_inner):
#      49 	self.n_updates += 1
# ---> 50 	grad_f = self.grad_free_energy(x)
#      51 	u_dot = tuple(
#      52 		llr.exp() * g.mul(-1.0) for g, llr
#      53 		in zip(grad_f, self.log_lr)
#      54 	)
#      55 	u_dot = tuple(
#      56 		self.softclamp(item, 'du')
#      57 		for item in u_dot
#      58 	)
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:504, in GaussianLayer.grad_free_energy(self, x)
#     502 eps = self.posterior.retrieve_noise(self.samples)
#     503 # (2) kl
# --> 504 grad_kl = self.grad_kl_term()
#     505 # (3) add up
#     506 grad_mu = grad_recon + grad_kl[0].mul(self.beta_inner)
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:494, in GaussianLayer.grad_kl_term(self)
#     492 # d/dxi kl
#     493 delta_xi = self.u[1] - self.u_prior[1]
# --> 494 grad_xi = torch.exp(2 * delta_xi) - 1.0
#     495 # put together
#     496 grad_kl = (grad_mu, grad_xi)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 2.00 MiB. GPU 1 has a total capacity of 47.51 GiB of which 2.44 MiB is free. Process 1025956 has 918.00 MiB memory in use. Including non-PyTorch memory, this process has 1.70 GiB memory in use. Process 1055438 has 44.88 GiB memory in use. Of the allocated memory 1.18 GiB is allocated by PyTorch, and 27.40 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %%
### Was: beta = 20.0
# Out:
# 100%|███████████████████████████████████| 2/2 [00:41<00:00, 20.82s/it]
# CPU times: user 50 s, sys: 2.79 s, total: 52.8 s
# Wall time: 52.8 s

# %% [markdown]
# ## output

# %%
output = tr.model.xtract_ftr(
    feeder=tr.get_feeder(),
    seq=range(1000),
    return_extras=True,
).stack()

# %%
u_norm = tonp(torch.linalg.norm(output['u'], axis=-1).mean(0))
v_norm = tonp(torch.linalg.norm(output['v'], axis=-1).mean(0))
r_norm = tonp(torch.linalg.norm(torch.exp(output['u']), axis=-1).mean(0))

fig, axes = create_figure(1, 3)
axes[0].plot(u_norm, label='u', color='r')
axes[1].plot(v_norm, label='v', color='k')
axes[2].plot(r_norm, label='r')

add_legend(axes)
plt.show()

# %%
### Was: beta = 20.0

# %%
feeder = tr.get_feeder()

locs = torch.stack([
    p.loc for p in
    output['conditional'].values()
], dim=1)

samples = torch.stack([
    p.sample() for p in
    output['conditional'].values()
], dim=1)

mse_locs = (locs - feeder[0].unsqueeze(1)).pow(2).sum(-1)
mse_samples = (samples - feeder[0].unsqueeze(1)).pow(2).sum(-1)

fig, ax = create_figure()
ax.plot(tonp(mse_locs.mean(0)), color='k', label='mean')
ax.plot(tonp(mse_samples.mean(0)), color='tomato', label='sample')
ax.set_yscale('log')
add_legend(ax)
plt.show()

mse_locs.mean(0)[-5:], mse_samples.mean(0)[-5:]
# Out:
# (tensor([81.5232, 79.1840, 86.9131, 39.7329, 31.3147], device='cuda:0'),
#  tensor([109.9722, 107.3562, 115.5772,  68.1607,  59.8281], device='cuda:0'))

# %%
num = 20
n_timepoints = 40

x2p = tonp(locs)[:num]
x2p = x2p[:, :n_timepoints]

true = tonp(feeder[0][:num].unsqueeze(1))
x2p = np.concatenate([x2p, np_nans(true.shape), true], axis=1)

x2p = x2p.reshape(tr.model.cfg.shape)
x2p = x2p.squeeze()

_ = plot_weights(x2p, nrows=num)

# %%
x2p = tonp(samples)[:num]
x2p = x2p[:, :n_timepoints]

true = tonp(feeder[0][:num].unsqueeze(1))
x2p = np.concatenate([x2p, np_nans(true.shape), true], axis=1)

x2p = x2p.reshape(tr.model.cfg.shape)
x2p = x2p.squeeze()

_ = plot_weights(x2p, nrows=num)
