# %% [markdown]
# # (23) mnist:  [128,  8, 8], 3
#
# **Motivation**: host = ```yoru```, device = ```cuda:0``` <br>
#
# This means:
# - ```K = 128```
# - ```M = 8```
# - ```S = 3```

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_TemporalSC'))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: yoru

# %% [markdown]
# ## Make a model

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('MNIST', model_type, 'ngd|lin')

t_train = 8

cfg_vae['t_train'] = t_train
cfg_vae['kl_beta'] = 4/8 * t_train

cfg_vae['latent_channels'] = 128
cfg_vae['latent_pixels'] = 8
cfg_vae['latent_stride'] = 3

cfg_vae['track_stats'] = True

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.n_iters
# Out:
# 120000

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |   22.7 K   |
# |     ———     |    ———     |
# |    layer    |   22.7 K   |
# +-------------+------------+
# poisson_MNIST_t-8_b-4_k-128_m-8_s-3_<ngd|lin>
# b200-ep400-lr(0.002)_temp(0.05)_gr(150)_(2025_06_22,14:17)

# %%
model.layer.n_exp
# Out:
# tensor([10, 10, 10, 10, 10, 10, 10, 10], device='cuda:0', dtype=torch.int32)

# %%
print(f"{tr.model.layer}\n{tr.model.layer.dec}")
# Out:
# PoissonLayer(latent_sz=(128, 8, 8), input_sz=(1, 28, 28), temp=1)
# ConvDictionary(in_channels=128, out_channels=1, kernel_size=7, stride=3)

# %%
tr.model.layer.dec.weight.shape
# Out:
# torch.Size([128, 1, 7, 7])

# %%
tr.train('ConvPhi:MNIST+K=128+M=8+S=3')
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Syncing run <strong><a href='https://wandb.ai/yateslab/_TemporalSC/runs/5qdry7pz' target="_blank">poisson_MNIST_t-8_b-4_k-128_m-8_s-3_<ngd|lin>/b200-ep400-lr(0.002)_temp(0.05)_gr(150)_ConvPhi:MNIST+K=128+M=8+S=3_(2025_06_22,14:17)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_TemporalSC/runs/5qdry7pz' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/5qdry7pz</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# Warning: Could not save notebook info: Can't identify the notebook path.
# epoch # 400, avg loss: 48.919: 100%|████████| 400/400 [4:32:08<00:00, 40.82s/it]
#  View run <strong style="color:#cdcd00">poisson_MNIST_t-8_b-4_k-128_m-8_s-3_<ngd|lin>/b200-ep400-lr(0.002)_temp(0.05)_gr(150)_ConvPhi:MNIST+K=128+M=8+S=3_(2025_06_22,14:17)</strong> at: <a href='https://wandb.ai/yateslab/_TemporalSC/runs/5qdry7pz' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/5qdry7pz</a><br> View project at: <a href='https://wandb.ai/yateslab/_TemporalSC' target="_blank">https://wandb.ai/yateslab/_TemporalSC</a><br>Synced 4 W&B file(s), 16 media file(s), 0 artifact file(s) and 38 other file(s)

# %%
tr.model.show();

# %%
# %%time

kws = dict(
    t_total=1000,
    n_data_batches=5,
    compute_sprs=False,
)
results = tr.analysis(dl='vld', **kws)
_ = plot_convergence(results, color='C0')
# Out:
# 100%|███████████████████████████████████| 5/5 [00:22<00:00,  4.55s/it]
# CPU times: user 31.5 s, sys: 10.3 s, total: 41.8 s
# Wall time: 41.8 s

# %%
a = 'poisson_vH16-wht_t-8_b-4_k-128_m-8_<ngd|lin>'
b = 'b200-ep300-lr(0.001)_temp(0.05)_gr(200)_ConvPhi:M=8_(2025_06_21,23:44)'
tr, meta = load_model(pjoin(a, b), device)
meta['checkpoint']
# Out:
# 300
