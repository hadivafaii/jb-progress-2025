# %% [markdown]
# # (22) conv latents:  [512, 4, 4]
#
# **Motivation**: host = ```chewie```, device = ```cuda:1``` <br>
#
# This means:
# - ```K = 512```
# - ```M = 4```

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_TemporalSC'))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 1
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:1  ———  host: chewie

# %% [markdown]
# ## Make a model

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('vH16-wht', model_type, 'ngd|lin')

t_train = 8

cfg_vae['t_train'] = t_train
cfg_vae['kl_beta'] = 4/8 * t_train
cfg_vae['n_latent_pixels'] = 4

cfg_vae['track_stats'] = True

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.n_iters
# Out:
# 154500

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  102.9 K   |
# |     ———     |    ———     |
# |    layer    |  102.9 K   |
# +-------------+------------+
# poisson_vH16-wht_t-8_b-4_k-512_m-4_<ngd|lin>
# b200-ep300-lr(0.001)_temp(0.05)_gr(200)_(2025_06_21,21:41)

# %%
model.layer.n_exp
# Out:
# tensor([50, 50, 50, 50, 50, 50, 50, 50], device='cuda:1', dtype=torch.int32)

# %%
print(f"{tr.model.layer}\n{tr.model.layer.dec}")
# Out:
# PoissonLayer(latent_sz=(512, 4, 4), input_sz=(1, 16, 16), temp=1)
# ConvDictionary(in_channels=512, out_channels=1, kernel_size=13)

# %%
tr.train('ConvPhi:M=4')
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Syncing run <strong><a href='https://wandb.ai/yateslab/_TemporalSC/runs/yv47zp66' target="_blank">poisson_vH16-wht_t-8_b-4_k-512_m-4_<ngd|lin>/b200-ep300-lr(0.001)_temp(0.05)_gr(200)_ConvPhi:M=4_(2025_06_21,21:41)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_TemporalSC/runs/yv47zp66' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/yv47zp66</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# Warning: Could not save notebook info: Can't identify the notebook path.
# epoch # 300, avg loss: 126.408: 100%|███████| 300/300 [3:55:10<00:00, 47.03s/it]
#  View run <strong style="color:#cdcd00">poisson_vH16-wht_t-8_b-4_k-512_m-4_<ngd|lin>/b200-ep300-lr(0.001)_temp(0.05)_gr(200)_ConvPhi:M=4_(2025_06_21,21:41)</strong> at: <a href='https://wandb.ai/yateslab/_TemporalSC/runs/yv47zp66' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/yv47zp66</a><br> View project at: <a href='https://wandb.ai/yateslab/_TemporalSC' target="_blank">https://wandb.ai/yateslab/_TemporalSC</a><br>Synced 4 W&B file(s), 12 media file(s), 0 artifact file(s) and 38 other file(s)

# %%
tr.model.show();

# %%
# %%time

kws = dict(
    t_total=1000,
    n_data_batches=10,
    compute_sprs=False,
)
results = tr.analysis(dl='vld', **kws)
_ = plot_convergence(results, color='C0')
# Out:
# 100%|█████████████████████████████████| 10/10 [01:38<00:00,  9.84s/it]
# CPU times: user 1min 39s, sys: 1min 12s, total: 2min 51s
# Wall time: 2min 53s
