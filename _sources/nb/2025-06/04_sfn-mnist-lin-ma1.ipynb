# %% [markdown]
# # (04) lin + mnist
#
# **Motivation**: host = ```mach```, device = ```cuda:1``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_iclr_ipvae'))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 1
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:1  ———  host: mach

# %% [markdown]
# ## setup config

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('MNIST', model_type, 'ngd|lin')

t_train = 8

cfg_vae['t_train'] = t_train
cfg_vae['kl_beta'] = 2/8 * t_train

cfg_vae['track_stats'] = True

# %% [markdown]
# ### Make model + trainer

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.n_iters
# Out:
# 120000

# %% [markdown]
# ### Print info

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  402.4 K   |
# |     ———     |    ———     |
# |    layer    |  402.4 K   |
# +-------------+------------+
# poisson_MNIST_t-8_b-2_k-512_<ngd|lin>
# b200-ep400-lr(0.002)_temp(0.05)_gr(150)_(2025_06_04,11:10)

# %%
model.layer.n_exp
# Out:
# tensor([50, 50, 50, 50, 50, 50, 50, 50], device='cuda:1', dtype=torch.int32)

# %%
print(f"{vars(tr.model.cfg)}\n\n\n{vars(tr.cfg)}")
# Out:
# {'prior_log_dist': 'uniform', 'clamp_prior': -4, 't_train': 8, 'kl_beta': 2.0, 'n_latents': 512, 'enc_type': 'ngd',
# 'dec_type': 'lin', 'recon_mode': 'mse', 'dataset': 'MNIST', 'dataset_name': 'MNIST', 'feeder': 'stationary',
# 'feeder_cfg': {}, 'input_sz': (1, 28, 28), 'shape': (-1, 1, 28, 28), 'init_dist': 'normal', 'init_scale': 0.0001,
# 'clamp_vals': {'u': (7.0,), 'du': (5.0,), 'dec': 3.45}, 'optim_sigma': False, 'stochastic': True, 'fit_prior':
# True, 'seed': 0, 'track_stats': True, 'base_dir': '/home/hadi/Projects/PoissonVAE', 'data_dir':
# '/home/hadi/Datasets', 'runs_dir': '/home/hadi/Projects/PoissonVAE/runs/poisson_MNIST_t-8_b-2_k-512_<ngd|lin>',
# 'mods_dir': '/home/hadi/Projects/PoissonVAE/models/poisson_MNIST_t-8_b-2_k-512_<ngd|lin>', 'results_dir':
# '/home/hadi/Projects/PoissonVAE/results'}
#
#
# {'lr': 0.002, 'epochs': 400, 'batch_size': 200, 'dataset_kws': None, 'warm_restart': 0, 'warmup_portion': 0.005,
# 'optimizer': 'adamax_fast', 'optimizer_kws': {'weight_decay': 0.001, 'betas': (0.9, 0.999), 'eps': 1e-08},
# 'scheduler_type': 'cosine', 'scheduler_kws': {'T_max': 398.0, 'eta_min': 1e-05}, 'ema_rate': None, 'grad_clip':
# 150, 'chkpt_freq': 20, 'eval_freq': 20, 'log_freq': 10, 'kl_beta_min': 0.0001, 'kl_const_portion': 0.001,
# 'kl_anneal_portion': 0.1, 'temp_anneal_portion': 0.5, 'temp_anneal_type': 'lin', 'temp_start': 1.0, 'temp_stop':
# 0.05}

# %%
print(tr.model.layer.dec)
# Out:
# Linear(
#   (_layer): Linear(in_features=512, out_features=784, bias=False)
# )

# %% [markdown]
# ### Fit model

# %%
tr.train('sfn')
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Syncing run <strong><a href='https://wandb.ai/yateslab/_iclr_ipvae/runs/bf6uoasf' target="_blank">poisson_MNIST_t-8_b-2_k-512_<ngd|lin>/b200-ep400-lr(0.002)_temp(0.05)_gr(150)_sfn_(2025_06_04,11:10)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_iclr_ipvae/runs/bf6uoasf' target="_blank">https://wandb.ai/yateslab/_iclr_ipvae/runs/bf6uoasf</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# Warning: Could not save notebook info: Can't identify the notebook path.
# epoch # 400, avg loss: 27.364: 100%|████████| 400/400 [1:40:43<00:00, 15.11s/it]
#  View run <strong style="color:#cdcd00">poisson_MNIST_t-8_b-2_k-512_<ngd|lin>/b200-ep400-lr(0.002)_temp(0.05)_gr(150)_sfn_(2025_06_04,11:10)</strong> at: <a href='https://wandb.ai/yateslab/_iclr_ipvae/runs/bf6uoasf' target="_blank">https://wandb.ai/yateslab/_iclr_ipvae/runs/bf6uoasf</a><br> View project at: <a href='https://wandb.ai/yateslab/_iclr_ipvae' target="_blank">https://wandb.ai/yateslab/_iclr_ipvae</a><br>Synced 4 W&B file(s), 16 media file(s), 0 artifact file(s) and 38 other file(s)

# %%
print(model.layer.n_exp)
# Out:
# tensor([36, 41, 44, 46, 46, 47, 47, 48], device='cuda:1', dtype=torch.int32)

# %%
u_max = np.array(tr.model.stats['u_max'])
du_max = np.array(tr.model.stats['du_max'])

fig, ax = create_figure()
ax.plot(u_max, color='k', label='u', lw=0.2)
ax.plot(du_max, color='r', label='du', alpha=0.7, lw=0.2)
ax.legend()
plt.show()

# %%
# %%time


results = tr.analysis(
    dl='vld',
    t_total=1000,
    n_data_batches=3,
)
_ = plot_convergence(results, color='C0')
# Out:
# 100%|███████████████████████████████████| 3/3 [00:09<00:00,  3.11s/it]
# CPU times: user 13 s, sys: 802 ms, total: 13.8 s
# Wall time: 13.8 s

# %%
u0 = tonp(tr.model.layer.u_init[0].squeeze())
tr.model.show(order=np.argsort(u0), dpi=400, pad=1);
# tr.model.show(order=None, dpi=400, pad=1);

# %%
u0 = tonp(tr.model.layer.u_init[0].squeeze())
bias = tonp(tr.model.layer.log_bias.exp().squeeze())

fig, axes = create_figure(1, 2, (10, 2))
kws = dict(fill=True, lw=3, alpha=0.3, ax=axes[0])
sns.histplot(u0, color='C0', element='step', label=r'$\log r$', **kws)

kws = dict(fill=True, lw=3, alpha=0.3, ax=axes[1])
sns.histplot(np.exp(u0), color='C0', element='step', label='rate', **kws)
sns.histplot(bias, color='C8', element='step', label='bias', **kws)

axes[1].set(ylabel='')
add_legend(axes)

plt.show()

# %%
(bias > 0).mean()
# Out:
# 1.0

# %%
mult = 1

results = tr.xtract_ftr(
    t_total=tr.model.cfg.t_train * mult,
    save_freq=mult,
    n_data_batches=10,
    data_batch_sz=2000,
    verbose=False,
)


fig, ax = create_figure(1, 1, (9, 3.5))
pal = get_cubehelix_palette(len(results['times']), start=2.5)

for i, t in enumerate(results['times']):
    sns.histplot(
        results['state_0'][:, i].ravel(),
        stat='percent',
        element='step',
        fill=False,
        color=pal[i],
        label=f"T = {t}",
        ax=ax,
    )
ax.legend(loc='upper left')
ax.grid()
plt.show()


fig, axes = create_figure(2, 1, (8, 5.8), sharex='col')
for i, t in enumerate(results['times']):
    for ax in axes.flat:
        sns.histplot(
            np.exp(results['state_0'][:, i].ravel()),
            stat='percent',
            element='step',
            fill=False,
            color=pal[i],
            label=f"T = {t}",
            ax=ax,
        )
axes[0].legend()
axes[1].set(yscale='log')
add_grid(axes)
plt.show()

# %%
pal
# Out:
# [[0.8975507056831679, 0.8094812603307622, 0.9465577040964425],
#  [0.79560472689218, 0.7025635211553574, 0.906794768375293],
#  [0.6686407796183966, 0.6049991340541501, 0.8494437689559234],
#  [0.5300158317387482, 0.5177020247219766, 0.7688253061707515],
#  [0.3958415626832449, 0.4388270462167934, 0.6665458619228831],
#  [0.26577992459661565, 0.3565507347057864, 0.5356429755155622],
#  [0.158519102797742, 0.271866265196377, 0.39112323360373646],
#  [0.07235872150128392, 0.17287618251766537, 0.23013648857700542]]

# %%
grad = np.array(list(tr.stats['grad'].values()))

fig, axes = create_figure(1, 2)
axes[0].plot(np.log(grad))
axes[1].plot(np.log(grad)[:300]);

# %%
(grad > 100).sum()
# Out:
# 0

# %%
# %%time


results = tr.analysis(
    dl='vld',
    t_total=1000,
    n_data_batches=-1,
)
_ = plot_convergence(results, color='k')
# Out:
# 100%|█████████████████████████████████| 50/50 [02:28<00:00,  2.97s/it]
# CPU times: user 3min 11s, sys: 12.4 s, total: 3min 23s
# Wall time: 3min 23s
