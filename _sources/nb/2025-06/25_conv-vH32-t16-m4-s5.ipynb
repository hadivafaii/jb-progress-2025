# %% [markdown]
# # (25) conv + vH32 + T16:  [512, 4, 4], 5
#
# **Motivation**: host = ```chewie```, device = ```cuda:1``` <br>
#
# This means:
#
# - ```K = 512```
# - ```M = 4```
# - ```S = 5```
#
# And:
#
# - ```T_train = 16```

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_TemporalSC'))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 1
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:1  ———  host: chewie

# %% [markdown]
# ## Make a model

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('vH32-wht', model_type, 'ngd|lin')

t_train = 16

cfg_vae['t_train'] = t_train
cfg_vae['kl_beta'] = 4/8 * t_train

cfg_vae['latent_channels'] = 512
cfg_vae['latent_pixels'] = 4
cfg_vae['latent_stride'] = 5

cfg_tr['batch_size'] = 100
cfg_tr['epochs'] = 400

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.n_iters
# Out:
# 180400

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  149.0 K   |
# |     ———     |    ———     |
# |    layer    |  149.0 K   |
# +-------------+------------+
# poisson_vH32-wht_t-16_b-8_k-512_m-4_s-5_<ngd|lin>
# b100-ep400-lr(0.001)_temp(0.05)_gr(200)_(2025_06_25,13:31)

# %%
model.layer.n_exp
# Out:
# tensor([10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#        device='cuda:1', dtype=torch.int32)

# %%
print(f"{tr.model.layer}\n{tr.model.layer.dec}")
# Out:
# PoissonLayer(latent_sz=(512, 4, 4), input_sz=(1, 32, 32), temp=1)
# ConvDictionary(in_channels=512, out_channels=1, kernel_size=17, stride=5)

# %%
tr.model.layer.dec.weight.shape
# Out:
# torch.Size([512, 1, 17, 17])

# %%
tr.model.layer.u_init[0].shape, tr.model.layer.log_bias.shape
# Out:
# (torch.Size([1, 512, 1, 1]), torch.Size([1, 512, 1, 1]))

# %%
tr.train('ConvPhiSpaceBroadcast')
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Syncing run <strong><a href='https://wandb.ai/yateslab/_TemporalSC/runs/1dzsm7v7' target="_blank">poisson_vH32-wht_t-16_b-8_k-512_m-4_s-5_<ngd|lin>/b100-ep400-lr(0.001)_temp(0.05)_gr(200)_ConvPhiSpaceBroadcast_(2025_06_25,13:31)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_TemporalSC/runs/1dzsm7v7' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/1dzsm7v7</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# Warning: Could not save notebook info: Can't identify the notebook path.
# epoch # 400, avg loss: 435.405: 100%|██████| 400/400 [10:33:55<00:00, 95.09s/it]
#  View run <strong style="color:#cdcd00">poisson_vH32-wht_t-16_b-8_k-512_m-4_s-5_<ngd|lin>/b100-ep400-lr(0.001)_temp(0.05)_gr(200)_ConvPhiSpaceBroadcast_(2025_06_25,13:31)</strong> at: <a href='https://wandb.ai/yateslab/_TemporalSC/runs/1dzsm7v7' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/1dzsm7v7</a><br> View project at: <a href='https://wandb.ai/yateslab/_TemporalSC' target="_blank">https://wandb.ai/yateslab/_TemporalSC</a><br>Synced 4 W&B file(s), 16 media file(s), 0 artifact file(s) and 38 other file(s)

# %%
tr.model.show();
tr.model.show(method='abs-max');

# %%
# %%time

kws = dict(
    t_total=1000,
    n_data_batches=5,
    compute_sprs=False,
)
results = tr.analysis(dl='vld', **kws)
_ = plot_convergence(results, color='C0')
# Out:
# 100%|███████████████████████████████████| 5/5 [00:14<00:00,  2.89s/it]
# CPU times: user 27.6 s, sys: 4.78 s, total: 32.4 s
# Wall time: 32.4 s

# %%
log_bias = tonp(tr.model.layer.log_bias.squeeze())
bias = np.exp(log_bias)
bias.shape
# Out:
# (512,)

# %%
fig, ax = create_figure(1, 1, (5, 2))
histplot(bias.ravel())
plt.show()

# %%
u0 = tonp(tr.model.layer.u_init[0].squeeze())
u0.shape
# Out:
# (512,)

# %%
histplot(u0.ravel())
plt.show()

# %%
print(sp_stats.pearsonr(u0.ravel(), log_bias.ravel()))
# Out:
# PearsonRResult(statistic=-0.478219192076544, pvalue=1.2834199153589476e-30)

# %%
# a = 'poisson_vH16-wht_t-8_b-4_k-128_m-8_<ngd|lin>'
# b = 'b200-ep300-lr(0.001)_temp(0.05)_gr(200)_ConvPhi:M=8_(2025_06_21,23:44)'
# tr, meta = load_model(pjoin(a, b), device)
# meta['checkpoint']
