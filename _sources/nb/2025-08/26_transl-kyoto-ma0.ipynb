# %% [markdown]
# # (26) Transl Kyoto: local dyna
#
# host = ```mach```, device = ```cuda:0```
#
# **Motivation**:  <br>
#
# - `speed` = 2.0 (anneal = 0.3)
# - `crop_size` = 32
# - $T_\text{train} = 16$
# - $T_\text{tbptt} = 16$
#
# lower lr

# %%
# HIDE CODE


project_name = '_TemporalSC'


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, project_name))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: mach

# %% [markdown]
# ## Make a model

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('Kyoto-wht+translate', model_type, 'ngd|lin')

cfg_vae['t_train'] = 32
cfg_vae['t_tbptt'] = 32
cfg_vae['kl_beta'] = 1.0

cfg_vae['latent_channels'] = 128
cfg_vae['latent_pixels'] = 10
cfg_vae['latent_stride'] = 4

cfg_vae['fwd_ker_u'] = 3
cfg_vae['fwd_ker_z'] = 5

cfg_vae['feeder_cfg'] = {'iters_per_epoch': 50, 'crop_size': 44, 'max_speed': 1.0}
cfg_vae['clamp_vals'] = {'u': (4.0,), 'du': (4.0,), 'dec': 3.45}

cfg_vae['recon_mode'] = 'mse'
cfg_vae['fit_sigma'] = False
cfg_vae['fit_dt'] = False

cfg_tr['lr'] = 5e-4
cfg_tr['epochs'] = 2400
cfg_tr['batch_size'] = 100
# cfg_tr['grad_clip'] = 1_000
# cfg_tr['warmup_portion'] = 0.01

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.feeder_trn.n_iters
# Out:
# 120000

# %%
# get var: learned & data
log_sigma = tonp(tr.model.layer.get_dec_log_sigma().squeeze())
var_init = (np.exp(2 * log_sigma)).reshape(tr.model.cfg.input_sz)
var_data = tonp(tr.feeder_trn.x.var(dim=0))

# plot
fig, axes =  create_figure(1, 2, (4.2, 1.5), width_ratios=[1, 1.2])
im = axes[0].imshow(var_init.mean(0), cmap='Greys_r')
plt.colorbar(im, ax=axes[0])
im = axes[1].imshow(var_data.mean(0), cmap='Greys_r')
plt.colorbar(im, ax=axes[1])

axes[0].set_title('var: init')
axes[1].set_title('var: data')

plt.show()

# print dt
try:
    lr_inner = tuple(dt.exp() for dt in tr.model.layer.log_dt)
except TypeError:
    lr_inner = None
print(f"learned inner learning rates (dt):\n\n{lr_inner}\n")
# Out:
# learned inner learning rates (dt):
#
# None

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  565.5 K   |
# |     ———     |    ———     |
# |    layer    |  565.5 K   |
# +-------------+------------+
# poisson_Kyoto-wht+translate_t-(32,32)_b-1_kms-(128,10,4)_fwd-(3,5)_<ngd|lin>
# b100-ep2400-lr(0.0005)_temp(0.05)_gr(200)_(2025_08_28,10:55)

# %%
model.layer.n_exp
# Out:
# tensor([10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#         10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#        device='cuda:0', dtype=torch.int32)

# %%
print(f"\n\n{tr.model.layer}\n\n{tr.model.layer.dec}\n")
# Out:
# PoissonLayer(latent_sz=(128, 10, 10), input_sz=(1, 44, 44), temp=1)
#
# ConvDictionary(in_channels=128, out_channels=1, kernel_size=8, stride=4)

# %%
print_num_params(tr.model.layer)
# Out:
# +--------------+------------+
# | Module Name  | Num Params |
# +--------------+------------+
# | PoissonLayer |  565.5 K   |
# |     ———      |    ———     |
# |     dec      |   8.2 K    |
# |   fwd_z.0    |  409.6 K   |
# |   fwd_u.0    |  147.5 K   |
# |    u_init    |    128     |
# +--------------+------------+

# %%
print(f"\n\n{vars(tr.model.cfg)}\n\n{vars(tr.cfg)}\n")
# Out:
# {'prior_log_dist': 'uniform', 'clamp_prior': -4, 't_train': 32, 't_tbptt': 32, 'kl_beta': 1.0, 'latent_channels':
# 128, 'latent_pixels': 10, 'latent_stride': 4, 'fwd_ker_u': 3, 'fwd_ker_z': 5, 'enc_type': 'ngd', 'dec_type': 'lin',
# 'recon_mode': 'mse', 'dataset': 'Kyoto-wht+translate', 'dataset_name': 'Kyoto-wht', 'feeder': 'translate',
# 'feeder_cfg': {'iters_per_epoch': 50, 'crop_size': 44, 'max_speed': 1.0, 'blur_sigma': 0.5, 'anneal_portion': 0.0,
# 'shift_rescale': True, 'snap_to_pixel': False, 'mode': 'bilinear'}, 'input_sz': (1, 44, 44), 'latent_sz': (128, 10,
# 10), 'init_dist': 'normal', 'init_scale': 0.0001, 'clamp_vals': {'u': (4.0,), 'du': (4.0,), 'dec': 3.45},
# 'stochastic': True, 'optim_sigma': False, 'fit_sigma': False, 'fit_prior': True, 'fit_dt': False, 'seed': 0,
# 'track_stats': False, 'base_dir': '/home/hadi/Projects/TemporalSC', 'data_dir': '/home/hadi/Datasets', 'runs_dir':
# '/home/hadi/Projects/TemporalSC/runs/poisson_Kyoto-wht+translate_t-(32,32)_b-1_kms-(128,10,4)_fwd-(3,5)_<ngd|lin>',
# 'mods_dir':
# '/home/hadi/Projects/TemporalSC/models/poisson_Kyoto-wht+translate_t-(32,32)_b-1_kms-(128,10,4)_fwd-(3,5)_<ngd|lin>
# ', 'results_dir': '/home/hadi/Projects/TemporalSC/results'}
#
# {'lr': 0.0005, 'epochs': 2400, 'batch_size': 100, 'dataset_kws': None, 'warm_restart': 0, 'warmup_portion': 0.005,
# 'optimizer': 'adamax_fast', 'optimizer_kws': {'weight_decay': 0.001, 'betas': (0.9, 0.999), 'eps': 1e-08},
# 'scheduler_type': 'cosine', 'scheduler_kws': {'T_max': 2388.0, 'eta_min': 1e-06}, 'ema_rate': None, 'grad_clip':
# 200, 'chkpt_freq': 50, 'eval_freq': 20, 'log_freq': 10, 'kl_beta_min': 0.0001, 'kl_const_portion': 0.001,
# 'kl_anneal_portion': 0.1, 'temp_anneal_portion': 0.5, 'temp_anneal_type': 'lin', 'temp_start': 1.0, 'temp_stop':
# 0.05}

# %%
comment = '_'.join([
    f"fwd:u{tr.model.cfg.fwd_ker_u}+z{tr.model.cfg.fwd_ker_z}",
    f"fit:{'dt' if tr.model.cfg.fit_dt else ''}+{'sig' if tr.model.cfg.fit_sigma else ''}",
    'Speed=1.0',
    'Anneal=0.0',
])
print(comment)
# Out:
# fwd:u3+z5_fit:+_Speed=1.0_Anneal=0.0

# %%
tr.train(comment=comment)
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Syncing run <strong><a href='https://wandb.ai/yateslab/_TemporalSC/runs/h49w0w2o' target="_blank">poisson_Kyoto-wht+translate_t-(32,32)_b-1_kms-(128,10,4)_fwd-(3,5)_<ngd|lin>/b100-ep2400-lr(0.0005)_temp(0.05)_gr(200)_fwd:u3+z5_fit:+_Speed=1.0_Anneal=0.0_(2025_08_28,10:55)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_TemporalSC/runs/h49w0w2o' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/h49w0w2o</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# Warning: Could not save notebook info: Can't identify the notebook path.
# epoch # 460, avg loss: 417.331:  19%|▌  | 459/2400 [3:52:47<16:24:27, 30.43s/it]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 tr.train(comment=comment)
#
# File ~/Dropbox/git/_TemporalSC/base/train_base.py:111, in BaseTrainer.train(self, comment, override_fit_name, epochs, fresh_fit, save)
#     109 	if (epoch + 1) % self.cfg.eval_freq == 0:
#     110 		gstep = (epoch + 1) * len(self.feeder_trn)
# --> 111 		self.validate(gstep)
#     112 if self.writer is not None:
#     113 	self.writer.close()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_TemporalSC/main/train.py:579, in Trainer.validate(self, gstep)
#     575 @torch.no_grad()
#     576 def validate(self, gstep: int = None):
#     577 	# extract features
#     578 	t_value = 1 if self.model.cfg.t_train == 1 else 1000
# --> 579 	results = self.xtract_ftr(
#     580 		data='vld',
#     581 		t_total=t_value,
#     582 		save_freq=t_value,
#     583 		n_data_batches=2,
#     584 		return_recon=True,
#     585 		verbose=False,
#     586 	)
#     587 	figs = None
#     588 	if gstep is not None:
#     589 		# sparsity
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_TemporalSC/main/train.py:711, in Trainer.xtract_ftr(self, data, t_total, save_freq, data_batch_sz, n_data_batches, return_recon, only_pos_r2, verbose)
#     709 # (2) stream data, fwd pass
#     710 x, *_ = feeder.step()
# --> 711 output = model.xtract_ftr(
#     712 	x=x, return_extras=items)
#     713 # (3) save
#     714 # tonp + append
#     715 for j in range(model.cfg.state_len):
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_TemporalSC/main/model.py:36, in _IterativeVAE.xtract_ftr(self, x, **kwargs)
#      34 temp = self.cfg.validation_temp
#      35 kwargs.setdefault('temp', temp)
# ---> 36 return self.forward(x, **kwargs)
#
# File ~/Dropbox/git/_TemporalSC/main/model.py:16, in _IterativeVAE.forward(self, x, temp, return_extras)
#      10 def forward(
#      11 		self,
#      12 		x: torch.Tensor,
#      13 		temp: float = None,
#      14 		return_extras: List[str] = None, ):
#      15 	# (1) bottom-up/top-down pass: infer/generate
# ---> 16 	loss_kl, loss_recon = self.layer(x, temp=temp)
#      17 	# (2) save values (main)
#      18 	output = {
#      19 		'loss_kl': loss_kl,
#      20 		'loss_recon': loss_recon,
#      21 		'posterior': self.layer.posterior,
#      22 	}
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Dropbox/git/_TemporalSC/main/layers.py:34, in _StochasticLayer.forward(self, x, temp)
#      32 # (1) generate from prior predictive
#      33 with self.temporary_temperature(temp):
# ---> 34 	self.update_generative_state()
#      35 # (2) perform inference + softclamp
#      36 du = self.encode(x)
#
# File ~/Dropbox/git/_TemporalSC/main/layers.py:206, in _StochasticLayer.update_generative_state(self)
#     203 validation = not torch.is_grad_enabled()
#     204 with self._grad_context():
#     205 	# (1) update posterior, samples
# --> 206 	self.update_inference_state()
#     207 	# (2) jacobian: grad is w.r.t. samples
#     208 	if validation:
#
# File ~/Dropbox/git/_TemporalSC/main/layers.py:220, in _StochasticLayer.update_inference_state(self)
#     219 def update_inference_state(self):
# --> 220 	self.update_posterior()
#     221 	if self.cfg.stochastic:
#     222 		self.samples_pre = self.posterior.rsample()
#
# File ~/Dropbox/git/_TemporalSC/main/layers.py:612, in PoissonLayer.update_posterior(self)
#     606 n_exp = (
#     607 	self.n_exp[self.time]
#     608 	if self.time < len(self.n_exp)
#     609 	else 'infer'
#     610 )
#     611 # (2) get dist
# --> 612 self.posterior = Poisson(
#     613 	log_rate=self.state[0],
#     614 	temp=self.temp.clone(),
#     615 	n_exp=n_exp,
#     616 	n_exp_p=1e-3,
#     617 	clamp=None,
#     618 )
#     619 return self.posterior
#
# File ~/Dropbox/git/_TemporalSC/main/distributions.py:27, in Poisson.__init__(self, log_rate, temp, clamp, n_exp, n_exp_p)
#      25 if n_exp == 'infer':
#      26 	max_rate = self.rate.max().item()
# ---> 27 	n_exp = compute_n_exp(max_rate, n_exp_p)
#      28 self.n_exp = int(n_exp)
#
# File ~/Dropbox/git/_TemporalSC/main/distributions.py:270, in compute_n_exp(rate, p)
#     269 def compute_n_exp(rate: float, p: float = 1e-6):
# --> 270 	assert rate > 0.0, f"must be positive, got: {rate}"
#     271 	pois = sp_stats.poisson(rate)
#     272 	n_exp = pois.ppf(1.0 - p)
#
# AssertionError: must be positive, got: nan

# %%
# %%time

results = tr.analysis('vld', t_total=1000, n_data_batches=5)
_ = plot_convergence(results=results, color='C0')
# Out:
#   0%|                                           | 0/5 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_TemporalSC/main/train.py:848, in Trainer.analysis(self, data, t_total, data_batch_sz, n_data_batches, active, return_recon, only_pos_r2, avg_samples, verbose)
#     846 # (2) stream data, fwd pass
#     847 x, *_ = feeder.step()
# --> 848 output = model.xtract_ftr(
#     849 	x=x, return_extras=items)
#     850 # (3) save
#     851 if (t + 1) == t_total:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:120, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     117 @functools.wraps(func)
#     118 def decorate_context(*args, **kwargs):
#     119     with ctx_factory():
# --> 120         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_TemporalSC/main/model.py:36, in _IterativeVAE.xtract_ftr(self, x, **kwargs)
#      34 temp = self.cfg.validation_temp
#      35 kwargs.setdefault('temp', temp)
# ---> 36 return self.forward(x, **kwargs)
#
# File ~/Dropbox/git/_TemporalSC/main/model.py:16, in _IterativeVAE.forward(self, x, temp, return_extras)
#      10 def forward(
#      11 		self,
#      12 		x: torch.Tensor,
#      13 		temp: float = None,
#      14 		return_extras: List[str] = None, ):
#      15 	# (1) bottom-up/top-down pass: infer/generate
# ---> 16 	loss_kl, loss_recon = self.layer(x, temp=temp)
#      17 	# (2) save values (main)
#      18 	output = {
#      19 		'loss_kl': loss_kl,
#      20 		'loss_recon': loss_recon,
#      21 		'posterior': self.layer.posterior,
#      22 	}
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1773, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1771     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772 else:
# -> 1773     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1784, in Module._call_impl(self, *args, **kwargs)
#    1779 # If we don't have any hooks, we want to skip the rest of the logic in
#    1780 # this function, and just call forward.
#    1781 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1782         or _global_backward_pre_hooks or _global_backward_hooks
#    1783         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784     return forward_call(*args, **kwargs)
#    1786 result = None
#    1787 called_always_called_hooks = set()
#
# File ~/Dropbox/git/_TemporalSC/main/layers.py:34, in _StochasticLayer.forward(self, x, temp)
#      32 # (1) generate from prior predictive
#      33 with self.temporary_temperature(temp):
# ---> 34 	self.update_generative_state()
#      35 # (2) perform inference + softclamp
#      36 du = self.encode(x)
#
# File ~/Dropbox/git/_TemporalSC/main/layers.py:206, in _StochasticLayer.update_generative_state(self)
#     203 validation = not torch.is_grad_enabled()
#     204 with self._grad_context():
#     205 	# (1) update posterior, samples
# --> 206 	self.update_inference_state()
#     207 	# (2) jacobian: grad is w.r.t. samples
#     208 	if validation:
#
# File ~/Dropbox/git/_TemporalSC/main/layers.py:220, in _StochasticLayer.update_inference_state(self)
#     219 def update_inference_state(self):
# --> 220 	self.update_posterior()
#     221 	if self.cfg.stochastic:
#     222 		self.samples_pre = self.posterior.rsample()
#
# File ~/Dropbox/git/_TemporalSC/main/layers.py:612, in PoissonLayer.update_posterior(self)
#     606 n_exp = (
#     607 	self.n_exp[self.time]
#     608 	if self.time < len(self.n_exp)
#     609 	else 'infer'
#     610 )
#     611 # (2) get dist
# --> 612 self.posterior = Poisson(
#     613 	log_rate=self.state[0],
#     614 	temp=self.temp.clone(),
#     615 	n_exp=n_exp,
#     616 	n_exp_p=1e-3,
#     617 	clamp=None,
#     618 )
#     619 return self.posterior
#
# File ~/Dropbox/git/_TemporalSC/main/distributions.py:27, in Poisson.__init__(self, log_rate, temp, clamp, n_exp, n_exp_p)
#      25 if n_exp == 'infer':
#      26 	max_rate = self.rate.max().item()
# ---> 27 	n_exp = compute_n_exp(max_rate, n_exp_p)
#      28 self.n_exp = int(n_exp)
#
# File ~/Dropbox/git/_TemporalSC/main/distributions.py:270, in compute_n_exp(rate, p)
#     269 def compute_n_exp(rate: float, p: float = 1e-6):
# --> 270 	assert rate > 0.0, f"must be positive, got: {rate}"
#     271 	pois = sp_stats.poisson(rate)
#     272 	n_exp = pois.ppf(1.0 - p)
#
# AssertionError: must be positive, got: nan

# %%
u0 = tonp(tr.model.layer.u_init[0].squeeze())
tr.model.show(order=np.argsort(u0));

# %%
output = tr.xtract_ftr(
    data='vld',
    t_total=32,
    save_freq=1,
    data_batch_sz=50,
    n_data_batches=1,
    return_recon=True,
    verbose=False,
)

# %%
num = 12
x2p = output['recon'][:num].reshape(-1, 32, 32)
_ = plot_weights(x2p, method='min-max', nrows=num, dpi=300)

# %%
log_bias = tonp(tr.model.layer.log_bias.squeeze())
bias = np.exp(log_bias)

fig, ax = create_figure(1, 1, (5, 2))
histplot(bias.ravel())
plt.show()

# %%
tr.model.show(order=np.argsort(bias));

# %%
histplot(u0.ravel())
plt.show()

# %%
print(sp_stats.pearsonr(u0.ravel(), log_bias.ravel()))

# %%
# get var: learned & data
log_sigma = tonp(tr.model.layer.get_dec_log_sigma().squeeze())
var_init = (np.exp(2 * log_sigma)).reshape(tr.model.cfg.input_sz)
var_data = tonp(tr.feeder_vld.x.var(dim=0))

# plot
fig, axes =  create_figure(1, 2, (6.2, 1.8))
im = axes[0].imshow(var_init.mean(0), cmap='Greys_r')
plt.colorbar(im, ax=axes[0])
im = axes[1].imshow(var_data.mean(0), cmap='Greys_r')
plt.colorbar(im, ax=axes[1])

axes[0].set_title('var: learned')
axes[1].set_title('var: data')

plt.show()

# print dt
lr_inner = tuple(dt.exp() for dt in tr.model.layer.log_dt)
print(f"learned inner learning rates (dt):\n\n{lr_inner}\n")
# Out:
# learned inner learning rates (dt):
#
# (tensor([0.4213], device='cuda:0', grad_fn=<ExpBackward0>),)
