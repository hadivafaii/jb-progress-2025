# %% [markdown]
# # (20) Rot MNIST: w/ dyna
#
# host = ```chewie```, device = ```cuda:0```
#
# **Motivation**:  <br>
#
# - $\Delta \theta = 4.0$
# - $T_\text{train} = 16$
# - $T_\text{tbptt} = 16$

# %%
# HIDE CODE


project_name = '_TemporalSC'


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, project_name))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: chewie

# %% [markdown]
# ## Make a model

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('MNIST+rotate', model_type, 'ngd|lin')

cfg_vae['t_train'] = 16
cfg_vae['t_tbptt'] = 16
cfg_vae['kl_beta'] = 1.0

cfg_vae['latent_channels'] = 128
cfg_vae['latent_pixels'] = 8
cfg_vae['latent_stride'] = 3

cfg_vae['fwd_groups'] = 1

cfg_vae['feeder_cfg'] = {'delta_theta': 4.0}
cfg_vae['clamp_vals'] = {'u': (4.0,), 'du': (4.0,), 'dec': 2.3}

cfg_vae['recon_mode'] = 'prob'
cfg_vae['fit_sigma'] = True
cfg_vae['fit_dt'] = True

cfg_tr['lr'] = 1e-3
cfg_tr['epochs'] = 200
cfg_tr['batch_size'] = 200
# cfg_tr['grad_clip'] = 3000
# cfg_tr['kl_const_portion'] = 0.0
# cfg_tr['kl_anneal_portion'] = 0.0

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.n_iters
# Out:
# 60000

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  957.8 K   |
# |     ———     |    ———     |
# |    layer    |  957.8 K   |
# +-------------+------------+
# poisson_MNIST+rotate_t-(16,16)_b-1_kms-(128,8,3)_uzg-(3,7,1)_prob_<ngd|lin>
# b200-ep200-lr(0.001)_temp(0.05)_gr(150)_(2025_08_22,08:15)

# %%
model.layer.n_exp
# Out:
# tensor([10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#        device='cuda:0', dtype=torch.int32)

# %%
print(f"\n\n{tr.model.layer}\n\n{tr.model.layer.dec}\n")
# Out:
# PoissonLayer(latent_sz=(128, 8, 8), input_sz=(1, 28, 28), temp=1)
#
# ConvDictionary(in_channels=128, out_channels=1, kernel_size=7, stride=3)

# %%
print_num_params(tr.model.layer)
# Out:
# +--------------+------------+
# | Module Name  | Num Params |
# +--------------+------------+
# | PoissonLayer |  957.8 K   |
# |     ———      |    ———     |
# |    log_dt    |     1      |
# |     dec      |   6.3 K    |
# |   fwd_u.0    |  147.6 K   |
# |   fwd_z.0    |  802.9 K   |
# |    u_init    |    128     |
# +--------------+------------+

# %%
print(f"\n\n{vars(tr.model.cfg)}\n\n{vars(tr.cfg)}\n")
# Out:
# {'prior_log_dist': 'uniform', 'clamp_prior': -4, 't_train': 16, 't_tbptt': 16, 'kl_beta': 1.0, 'latent_channels':
# 128, 'latent_pixels': 8, 'latent_stride': 3, 'fwd_u_ker_sz': 3, 'fwd_z_ker_sz': 7, 'fwd_groups': 1, 'enc_type':
# 'ngd', 'dec_type': 'lin', 'recon_mode': 'prob', 'dataset': 'MNIST+rotate', 'dataset_name': 'MNIST', 'feeder':
# 'rotate', 'feeder_cfg': {'delta_theta': 4.0, 'theta_0': None}, 'input_sz': (1, 28, 28), 'latent_sz': (128, 8, 8),
# 'init_dist': 'normal', 'init_scale': 0.0001, 'clamp_vals': {'u': (4.0,), 'du': (4.0,), 'dec': 2.3}, 'stochastic':
# True, 'optim_sigma': False, 'fit_sigma': True, 'fit_prior': True, 'fit_dt': True, 'seed': 0, 'track_stats': False,
# 'base_dir': '/home/hadi/Projects/TemporalSC', 'data_dir': '/home/hadi/Datasets', 'runs_dir':
# '/home/hadi/Projects/TemporalSC/runs/poisson_MNIST+rotate_t-(16,16)_b-1_kms-(128,8,3)_uzg-(3,7,1)_prob_<ngd|lin>',
# 'mods_dir':
# '/home/hadi/Projects/TemporalSC/models/poisson_MNIST+rotate_t-(16,16)_b-1_kms-(128,8,3)_uzg-(3,7,1)_prob_<ngd|lin>'
# , 'results_dir': '/home/hadi/Projects/TemporalSC/results'}
#
# {'lr': 0.001, 'epochs': 200, 'batch_size': 200, 'dataset_kws': None, 'warm_restart': 0, 'warmup_portion': 0.005,
# 'optimizer': 'adamax_fast', 'optimizer_kws': {'weight_decay': 0.001, 'betas': (0.9, 0.999), 'eps': 1e-08},
# 'scheduler_type': 'cosine', 'scheduler_kws': {'T_max': 199.0, 'eta_min': 1e-06}, 'ema_rate': None, 'grad_clip':
# 150, 'chkpt_freq': 20, 'eval_freq': 20, 'log_freq': 10, 'kl_beta_min': 0.0001, 'kl_const_portion': 0.001,
# 'kl_anneal_portion': 0.1, 'temp_anneal_portion': 0.5, 'temp_anneal_type': 'lin', 'temp_start': 1.0, 'temp_stop':
# 0.05}

# %%
tr.train('fwd:u3+z7_fit:dt+sigma')
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Syncing run <strong><a href='https://wandb.ai/yateslab/_TemporalSC/runs/s8at7yq6' target="_blank">poisson_MNIST+rotate_t-(16,16)_b-1_kms-(128,8,3)_uzg-(3,7,1)_prob_<ngd|lin>/b200-ep200-lr(0.001)_temp(0.05)_gr(150)_fwd:u3+z7_fit:dt+sigma_(2025_08_22,08:15)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_TemporalSC/runs/s8at7yq6' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/s8at7yq6</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# Warning: Could not save notebook info: Can't identify the notebook path.
# epoch # 200, avg loss: -853.001: 100%|█████| 200/200 [6:40:07<00:00, 120.04s/it]
#  View run <strong style="color:#cdcd00">poisson_MNIST+rotate_t-(16,16)_b-1_kms-(128,8,3)_uzg-(3,7,1)_prob_<ngd|lin>/b200-ep200-lr(0.001)_temp(0.05)_gr(150)_fwd:u3+z7_fit:dt+sigma_(2025_08_22,08:15)</strong> at: <a href='https://wandb.ai/yateslab/_TemporalSC/runs/s8at7yq6' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/s8at7yq6</a><br> View project at: <a href='https://wandb.ai/yateslab/_TemporalSC' target="_blank">https://wandb.ai/yateslab/_TemporalSC</a><br>Synced 4 W&B file(s), 8 media file(s), 0 artifact file(s) and 38 other file(s)

# %%
# %%time

results = tr.analysis('vld', t_total=1000, n_data_batches=5)
_ = plot_convergence(results=results, color='C0')
# Out:
# 100%|███████████████████████████████████| 5/5 [00:12<00:00,  2.48s/it]
# CPU times: user 13.3 s, sys: 43.9 ms, total: 13.3 s
# Wall time: 13.4 s

# %%
u0 = tonp(tr.model.layer.u_init[0].squeeze())
tr.model.show(order=np.argsort(u0));

# %%
output = tr.xtract_ftr(
    data='vld',
    t_total=32,
    save_freq=1,
    data_batch_sz=50,
    n_data_batches=1,
    return_recon=True,
    verbose=False,
)

# %%
num = 12
x2p = output['recon'][:num].reshape(-1, 28, 28)
_ = plot_weights(x2p, method='min-max', nrows=num, dpi=300)

# %%
histplot(output['recon'][:, 0].ravel(), stat='percent')
histplot(output['recon'][:, 1:].ravel(), stat='percent');

# %%
log_bias = tonp(tr.model.layer.log_bias.squeeze())
bias = np.exp(log_bias)

fig, ax = create_figure(1, 1, (5, 2))
histplot(bias.ravel())
plt.show()

# %%
tr.model.show(order=np.argsort(bias));

# %%
histplot(u0.ravel())
plt.show()

# %%
print(sp_stats.pearsonr(u0.ravel(), log_bias.ravel()))
# Out:
# PearsonRResult(statistic=-0.66324395, pvalue=1.4658721156130153e-17)

# %%
w = tonp(tr.model.layer.fwd_z[0].weight)
histplot(w.ravel())
# Out:
# <Axes: ylabel='Count'>

# %%
w = tonp(tr.model.layer.fwd_u[0].weight)
histplot(w.ravel())
# Out:
# <Axes: ylabel='Count'>

# %%
plot_weights(w[0]);
plot_weights(w[100]);

# %%
w.shape
# Out:
# (128, 128, 7, 7)

# %%
plot_weights(w[0]);
plot_weights(w[100]);
