# %% [markdown]
# # (30) Rot MNIST: fwd(1+3)
#
# host = ```chewie```, device = ```cuda:1```
#
# **Motivation**:  <br>
#
# - $\Delta \theta = 2.0$
# - $T_\text{train} = 32$
# - $T_\text{tbptt} = 32$
#
# tighter decoder sigma clamp (`0.8` instead of `1.15`)

# %%
# HIDE CODE


project_name = '_TemporalSC'


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, project_name))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 1
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:1  ———  host: chewie

# %% [markdown]
# ## Best model that worked so far

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('MNIST+rotate', model_type, 'ngd|lin')

cfg_vae['t_train'] = 32
cfg_vae['t_tbptt'] = 32
cfg_vae['kl_beta'] = 4.0

cfg_vae['latent_channels'] = 192
cfg_vae['latent_pixels'] = 8
cfg_vae['latent_stride'] = 3

cfg_vae['fwd_ker_u'] = 1
cfg_vae['fwd_ker_z'] = 3

cfg_vae['feeder_cfg'] = {'max_delta_theta': 2.0}
cfg_vae['clamp_vals'] = {'u': (4.0,), 'du': (4.0,), 'dec': 0.8}

cfg_vae['recon_mode'] = 'prob'
cfg_vae['fit_sigma'] = True
cfg_vae['fit_dt'] = True
cfg_vae['fit_bias'] = False

cfg_tr['lr'] = 5e-4
cfg_tr['epochs'] = 300
cfg_tr['batch_size'] = 100

# cfg_tr['warmup_portion'] = 0.01

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.feeder_trn.n_iters
# Out:
# 180000

# %%
# _ = tr.data_dependent_init(t_total=200, n_data_batches=5, data_batch_sz=5000)

# %%
# get var: learned & data
log_sigma = tonp(tr.model.layer.get_dec_log_sigma().squeeze())
var_init = (np.exp(2 * log_sigma)).reshape(tr.model.cfg.input_sz)
var_data = tonp(tr.feeder_vld.x.var(dim=0))

# plot
fig, axes =  create_figure(1, 2, (4.2, 1.7), sharex='all', sharey='all')
im = axes[0].imshow(var_init.mean(0), cmap='Greys_r')
plt.colorbar(im, ax=axes[0])
im = axes[1].imshow(var_data.mean(0), cmap='Greys_r')
plt.colorbar(im, ax=axes[1])

axes[0].set_title('var: init')
axes[1].set_title('var: data')

plt.show()

# print dt
lr_inner = tuple(dt.exp() for dt in tr.model.layer.log_dt)
print(f"learned inner learning rates (dt):\n\n{lr_inner}\n")
# Out:
# learned inner learning rates (dt):
#
# (tensor([1.], device='cuda:1', grad_fn=<ExpBackward0>),)

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  379.0 K   |
# |     ———     |    ———     |
# |    layer    |  379.0 K   |
# +-------------+------------+
# poisson_MNIST+rotate_t-(32,32)_b-4_kms-(192,8,3)_fwd-(1,3)_prob_<ngd|lin>
# b100-ep300-lr(0.0005)_temp(0.05)_gr(250)_(2025_09_01,20:42)

# %%
model.layer.n_exp
# Out:
# tensor([10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#         10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#        device='cuda:1', dtype=torch.int32)

# %%
print(f"\n\n{tr.model.layer}\n\n{tr.model.layer.dec}\n")
# Out:
# PoissonLayer(latent_sz=(192, 8, 8), input_sz=(1, 28, 28), temp=1)
#
# ConvDictionary(in_channels=192, out_channels=1, kernel_size=7, stride=3)

# %%
print_num_params(tr.model.layer)
# Out:
# +--------------+------------+
# | Module Name  | Num Params |
# +--------------+------------+
# | PoissonLayer |  379.0 K   |
# |     ———      |    ———     |
# |    log_dt    |     1      |
# |     dec      |   9.4 K    |
# |   fwd_z.0    |  331.8 K   |
# |   fwd_u.0    |   36.9 K   |
# |    u_init    |    192     |
# +--------------+------------+

# %%
print(f"\n\n{vars(tr.model.cfg)}\n\n{vars(tr.cfg)}\n")
# Out:
# {'prior_log_dist': 'uniform', 'clamp_prior': -4, 't_train': 32, 't_tbptt': 32, 'kl_beta': 4.0, 'latent_channels':
# 192, 'latent_pixels': 8, 'latent_stride': 3, 'fwd_ker_u': 1, 'fwd_ker_z': 3, 'enc_type': 'ngd', 'dec_type': 'lin',
# 'recon_mode': 'prob', 'dataset': 'MNIST+rotate', 'dataset_name': 'MNIST', 'feeder': 'rotate', 'feeder_cfg':
# {'max_delta_theta': 2.0, 'theta_0': None, 'anneal_portion': 0.0}, 'input_sz': (1, 28, 28), 'latent_sz': (192, 8,
# 8), 'init_dist': 'normal', 'init_scale': 0.0001, 'clamp_vals': {'u': (4.0,), 'du': (4.0,), 'dec': 0.8},
# 'stochastic': True, 'optim_sigma': False, 'fit_sigma': True, 'fit_prior': True, 'fit_bias': False, 'fit_dt': True,
# 'seed': 0, 'track_stats': False, 'base_dir': '/home/hadi/Projects/TemporalSC', 'data_dir': '/home/hadi/Datasets',
# 'runs_dir':
# '/home/hadi/Projects/TemporalSC/runs/poisson_MNIST+rotate_t-(32,32)_b-4_kms-(192,8,3)_fwd-(1,3)_prob_<ngd|lin>',
# 'mods_dir':
# '/home/hadi/Projects/TemporalSC/models/poisson_MNIST+rotate_t-(32,32)_b-4_kms-(192,8,3)_fwd-(1,3)_prob_<ngd|lin>',
# 'results_dir': '/home/hadi/Projects/TemporalSC/results'}
#
# {'lr': 0.0005, 'epochs': 300, 'batch_size': 100, 'dataset_kws': None, 'warm_restart': 0, 'warmup_portion': 0.005,
# 'optimizer': 'adamax_fast', 'optimizer_kws': {'weight_decay': 0.0001, 'betas': (0.9, 0.999), 'eps': 1e-08},
# 'scheduler_type': 'cosine', 'scheduler_kws': {'T_max': 298.5, 'eta_min': 5e-08}, 'ema_rate': None, 'grad_clip':
# 250, 'chkpt_freq': 20, 'eval_freq': 20, 'log_freq': 10, 'kl_beta_min': 0.0001, 'kl_const_portion': 0.001,
# 'kl_anneal_portion': 0.1, 'temp_anneal_portion': 0.5, 'temp_anneal_type': 'lin', 'temp_start': 1.0, 'temp_stop':
# 0.05}

# %%
comment = '_'.join([
    f"fwd:lamb{tr.model.cfg.fwd_ker_u}+z{tr.model.cfg.fwd_ker_z}",
    f"fit:{'dt' if tr.model.cfg.fit_dt else ''}+{'sig' if tr.model.cfg.fit_sigma else ''}",
    'ClampDec:1.15',
    'dontfitbias',
])
print(comment)
# Out:
# fwd:lamb1+z3_fit:dt+sig_ClampDec:1.15_dontfitbias

# %%
tr.train(comment=comment)
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Syncing run <strong><a href='https://wandb.ai/yateslab/_TemporalSC/runs/61a6a7yh' target="_blank">poisson_MNIST+rotate_t-(32,32)_b-4_kms-(192,8,3)_fwd-(1,3)_prob_<ngd|lin>/b100-ep300-lr(0.0005)_temp(0.05)_gr(250)_fwd:lamb1+z3_fit:dt+sig_ClampDec:1.15_dontfitbias_(2025_09_01,20:42)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_TemporalSC/runs/61a6a7yh' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/61a6a7yh</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# Warning: Could not save notebook info: Can't identify the notebook path.
# epoch # 300, avg loss: 105.884: 100%|█████| 300/300 [28:57:19<00:00, 347.47s/it]
#  View run <strong style="color:#cdcd00">poisson_MNIST+rotate_t-(32,32)_b-4_kms-(192,8,3)_fwd-(1,3)_prob_<ngd|lin>/b100-ep300-lr(0.0005)_temp(0.05)_gr(250)_fwd:lamb1+z3_fit:dt+sig_ClampDec:1.15_dontfitbias_(2025_09_01,20:42)</strong> at: <a href='https://wandb.ai/yateslab/_TemporalSC/runs/61a6a7yh' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/61a6a7yh</a><br> View project at: <a href='https://wandb.ai/yateslab/_TemporalSC' target="_blank">https://wandb.ai/yateslab/_TemporalSC</a><br>Synced 4 W&B file(s), 12 media file(s), 0 artifact file(s) and 39 other file(s)

# %% [markdown]
# ## observe:
#
# fit_bias = False: help or hurt?
#
# Trying to reproduce this: https://wandb.ai/yateslab/_TemporalSC/runs/dvyetrxh/overview

# %%
print(model.layer.n_exp)
# Out:
# tensor([19, 36, 43, 42, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41, 41,
#         41, 41, 41, 41, 41, 42, 41, 41, 41, 42, 41, 41, 41, 41],
#        device='cuda:1', dtype=torch.int32)

# %%
# %%time

results = tr.analysis('vld', t_total=1000, n_data_batches=5)
_ = plot_convergence(results=results, color='C0')
# Out:
# 100%|███████████████████████████████████| 5/5 [00:12<00:00,  2.46s/it]
# CPU times: user 13.4 s, sys: 2.32 ms, total: 13.4 s
# Wall time: 13.4 s

# %%
# %%time

results = tr.analysis('vld', t_total=1000, n_data_batches=-1)
_ = plot_convergence(results=results, color='C0')

# %%
u0 = tonp(tr.model.layer.u_init[0].squeeze())
tr.model.show(order=np.argsort(u0), method='min-max');

# %%
# get var: learned & data
log_sigma = tonp(tr.model.layer.get_dec_log_sigma().squeeze())
var_init = (np.exp(2 * log_sigma)).reshape(tr.model.cfg.input_sz)
var_data = tonp(tr.feeder_vld.x.var(dim=0))

# plot
fig, axes =  create_figure(1, 2, (6.2, 1.8), sharex='all', sharey='all')
im = axes[0].imshow(var_init.mean(0), cmap='Greys_r')
plt.colorbar(im, ax=axes[0])
im = axes[1].imshow(var_data.mean(0), cmap='Greys_r')
plt.colorbar(im, ax=axes[1])

axes[0].set_title('var: learned')
axes[1].set_title('var: data')

plt.show()

# print dt
lr_inner = tuple(dt.exp() for dt in tr.model.layer.log_dt)
print(f"learned inner learning rates (dt):\n\n{lr_inner}\n")
# Out:
# learned inner learning rates (dt):
#
# (tensor([0.0979], device='cuda:1', grad_fn=<ExpBackward0>),)

# %%
# u0 = tonp(tr.model.layer.u_init[0].squeeze())
# bias = tonp(tr.model.layer.log_bias.squeeze().exp())
weight_norms = tonp(torch.linalg.vector_norm(
    tr.model.layer.get_weight(), dim=(1, 2, 3)))

tr.model.show(order=np.argsort(weight_norms), method='min-max');
