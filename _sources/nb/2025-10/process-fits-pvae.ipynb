# %% [markdown]
# # process fits, save results (pvae)
#
# project = ```P-VAE```, host = ```chewie```, device = ```cuda:1```
#
# **Motivation**: <br>
#
# From ```Dropbox/chkpts/PoissonVAE``` to ```../tmp/results_2025-10```
#
# Goal: `MetabolicCost`

# %%
# HIDE CODE


project_name = 'PoissonVAE'


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, project_name))
from figures.fighelper import *
from main.train_vae import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
from analysis.final import perform_analysis


device_idx = 1
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:1  ———  host: mach

# %% [markdown]
# ## Results dir

# %%
results_dir = pjoin(tmp_dir, 'results_2025-10')
os.makedirs(results_dir, exist_ok=True)

len(os.listdir(results_dir))
# Out:
# 128

# %% [markdown]
# ## Run the loop

# %%
# %%time

perform_analysis(results_dir, device, override_fits=True, verbose=True)
# Out:
#   1%|▏                                          | 1/179 [00:02<08:27,  2.85s/it]
# [PROGRESS] 'gaussian+relu-<conv+b|lin>-vH16-b-1_k-512-amort_chewie-0_(2025_10_16,16:00).npy' saved at
# /home/hadi/Dropbox/git/jb-progress-2025/tmp/results_2025-10
#   1%|▍                                          | 2/179 [00:06<09:03,  3.07s/it]
# [PROGRESS] 'gaussian+relu-<lin|lin>-vH16-b-0.01_k-1024-MetabolicCost_chewie-0_(2025_10_12,17:29).npy' saved at
# /home/hadi/Dropbox/git/jb-progress-2025/tmp/results_2025-10
#   2%|▋                                          | 3/179 [00:07<06:08,  2.09s/it]
# [PROGRESS] 'gaussian+relu-<lin|lin>-vH16-b-0.01_k-128-MetabolicCost_chewie-0_(2025_10_12,16:13).npy' saved at
# /home/hadi/Dropbox/git/jb-progress-2025/tmp/results_2025-10
#   2%|▉                                          | 4/179 [00:08<04:54,  1.68s/it]
# [PROGRESS] 'gaussian+relu-<lin|lin>-vH16-b-0.01_k-192-MetabolicCost_mach-0_(2025_11_26,17:23).npy' saved at
# ...
