# %% [markdown]
# # tmp — oct25
#
# **Motivation**: scratch notebook <br>

# %%
# HIDE CODE


project_name = '_TemporalSC'


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, project_name))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: mach

# %%
root = 'Dropbox/chkpts/PoissonVAE'
root = add_home(root)

fits_pvae = [f for f in sorted(os.listdir(root), key=alphanum_sort_key)]
fits_metabolic_cost = [f for f in fits_pvae if 'MetabolicCost' in f]
fits_amort_beta1 = [f for f in fits_pvae if all(e in f for e in ('vH16', 'amort', '_b-1_'))]

len(fits_pvae), len(fits_metabolic_cost), len(fits_amort_beta1)
# Out:
# (272, 128, 4)

# %%
print(fits_amort_beta1)
# Out:
# [
#     'gaussian-<conv+b|lin>-vH16-amort_b-1_yoru-1_(2025_03_13,06:35)',
#     'gaussian-<conv+b|lin>-vH16-amort_b-1_yoru-1_(2025_03_13,06:37)',
#     'gaussian-<conv+b|lin>-vH16-amort_b-1_yoru-1_(2025_03_14,09:12)',
#     'poisson-<conv+b|lin>-vH16-amort_b-1_yoru-1_(2025_03_14,18:32)'
# ]

# %%
df_ratedist = 'Dropbox/git/IterativeVAE/results/df_ratedist.df'
df_ratedist = pd.read_pickle(add_home(df_ratedist))
df_ratedist.shape
# Out:
# (141, 11)

# %%
df_ratedist
# Out:
#          type latent_act                str_model  seq_len  kl_beta  amort  \
# 0    gaussian       relu      gaussian+relu+amort        1     0.10   True
# 1    gaussian       relu      gaussian+relu+amort        1     0.01   True
# 2    gaussian   softplus  gaussian+softplus+amort        1     0.01   True
# 3    gaussian   softplus  gaussian+softplus+amort        1     0.10   True
# 4    gaussian       None           gaussian+amort        1     0.10   True
# ..        ...        ...                      ...      ...      ...    ...
# 136  gaussian       relu            gaussian+relu       32    20.00  False
# 137  gaussian       relu            gaussian+relu       32    24.00  False
# 138  gaussian       relu            gaussian+relu       32    32.00  False
# 139  gaussian       relu            gaussian+relu       32    48.00  False
# 140  gaussian       relu            gaussian+relu       32    64.00  False
#
#       %-zeros        r2    r2_map  distance  distance_map
# ...

# %%
print(collections.Counter(df_ratedist['str_model']))
# Out:
# Counter({
#     'gaussian+relu+amort': 12,
#     'gaussian+softplus+amort': 12,
#     'gaussian+amort': 12,
#     'gaussian': 24,
#     'lca': 19,
#     'poisson+amort': 12,
#     'poisson': 24,
#     'gaussian+relu': 26
# })

# %%
root = 'Dropbox/chkpts/PoissonVAE'
root = add_home(root)

[
    f for f in sorted(os.listdir(root), key=alphanum_sort_key)
    if 'poisson' in f]
# Out:
# ['poisson-<lin|lin>-vH16-b-0.01_k-32-MetabolicCost_mach-0_(2025_10_12,15:48)',
#  'poisson-<lin|lin>-vH16-b-0.1_k-32-MetabolicCost_mach-0_(2025_10_12,22:11)',
#  'poisson-<lin|lin>-vH16-b-0.01_k-64-MetabolicCost_mach-0_(2025_10_12,15:52)',
#  'poisson-<lin|lin>-vH16-b-0.1_k-64-MetabolicCost_mach-0_(2025_10_12,23:25)',
#  'poisson-<lin|lin>-vH16-b-0.01_k-128-MetabolicCost_mach-0_(2025_10_12,16:12)',
#  'poisson-<lin|lin>-vH16-b-0.1_k-128-MetabolicCost_mach-0_(2025_10_12,19:50)',
#  'poisson-<lin|lin>-vH16-b-0.01_k-512-MetabolicCost_mach-0_(2025_10_12,17:42)',
#  'poisson-<lin|lin>-vH16-b-0.1_k-512-MetabolicCost_mach-0_(2025_10_12,21:17)',
#  'poisson-<lin|lin>-vH16-b-0.01_k-768-MetabolicCost_mach-0_(2025_10_12,20:20)',
#  'poisson-<lin|lin>-vH16-b-0.1_k-768-MetabolicCost_mach-0_(2025_10_13,02:08)',
#  'poisson-<lin|lin>-vH16-b-0.01_k-1024-MetabolicCost_mach-0_(2025_10_12,21:29)',
#  'poisson-<lin|lin>-vH16-b-0.1_k-1024-MetabolicCost_mach-0_(2025_10_13,04:07)',
# ...
