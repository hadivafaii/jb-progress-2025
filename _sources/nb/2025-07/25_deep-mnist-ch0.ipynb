# %% [markdown]
# # (25) deep dec — mnist
#
# **Motivation**: host = ```chewie```, device = ```cuda:0``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_TemporalSC'))
from figures.convergence import plot_convergence
from main.config_defaults import default_configs
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: chewie

# %% [markdown]
# ## Make a model

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('MNIST', model_type, 'ngd|deep')

t_train = 16

cfg_vae['t_train'] = t_train
cfg_vae['kl_beta'] = 1/16 * t_train

cfg_vae['latent_channels'] = 128
cfg_vae['latent_pixels'] = 3

# cfg_tr['batch_size'] = 100
# cfg_tr['epochs'] = 40

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.n_iters
# Out:
# 120000

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  2.6 Mil   |
# |     ———     |    ———     |
# |    layer    |  2.6 Mil   |
# +-------------+------------+
# poisson_MNIST_t-16_b-1_kms-(128,3,1)_<ngd|deep>
# b200-ep400-lr(0.002)_temp(0.05)_gr(150)_(2025_07_25,23:41)

# %%
model.layer.n_exp
# Out:
# tensor([10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10],
#        device='cuda:0', dtype=torch.int32)

# %%
print(f"{tr.model.layer}") # \n{tr.model.layer.dec}")
# Out:
# PoissonLayer(latent_sz=(128, 3, 3), input_sz=(1, 28, 28), temp=1)

# %%
print_num_params(tr.model.layer.dec)
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |  Sequential |  2.6 Mil   |
# |     ———     |    ———     |
# |      0      |   66.0 K   |
# |      1      |  1.3 Mil   |
# |      2      |  598.5 K   |
# |      3      |  330.1 K   |
# |      4      |  149.8 K   |
# |      5      |   82.6 K   |
# |      6      |   37.5 K   |
# |      8      |     65     |
# +-------------+------------+

# %%
tr.model.layer.u_init[0].shape, tr.model.layer.log_bias.shape
# Out:
# (torch.Size([1, 128, 1, 1]), torch.Size([1, 128, 1, 1]))

# %%
tr.model.layer.dec[0]
# Out:
# Conv2D(
#   (_layer): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), padding=valid)
# )

# %%
tr.train('expand=4')
# Out:
# wandb: ERROR Failed to detect the name of this notebook. You can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# Syncing run <strong><a href='https://wandb.ai/yateslab/_TemporalSC/runs/nvrxm7o2' target="_blank">poisson_MNIST_t-16_b-1_kms-(128,3,1)_<ngd|deep>/b200-ep400-lr(0.002)_temp(0.05)_gr(150)_expand=4_(2025_07_25,23:41)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_TemporalSC/runs/nvrxm7o2' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/nvrxm7o2</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# Warning: Could not save notebook info: Can't identify the notebook path.
# epoch # 400, avg loss: 10.002: 100%|██████| 400/400 [21:43:10<00:00, 195.48s/it]
#  View run <strong style="color:#cdcd00">poisson_MNIST_t-16_b-1_kms-(128,3,1)_<ngd|deep>/b200-ep400-lr(0.002)_temp(0.05)_gr(150)_expand=4_(2025_07_25,23:41)</strong> at: <a href='https://wandb.ai/yateslab/_TemporalSC/runs/nvrxm7o2' target="_blank">https://wandb.ai/yateslab/_TemporalSC/runs/nvrxm7o2</a><br> View project at: <a href='https://wandb.ai/yateslab/_TemporalSC' target="_blank">https://wandb.ai/yateslab/_TemporalSC</a><br>Synced 4 W&B file(s), 12 media file(s), 0 artifact file(s) and 38 other file(s)

# %%
# %%time

kws = dict(
    t_total=1000,
    n_data_batches=5,
    compute_sprs=False,
)
results = tr.analysis('vld', **kws)
_ = plot_convergence(results, color='C0')
# Out:
# 100%|███████████████████████████████████| 5/5 [01:07<00:00, 13.47s/it]
# CPU times: user 1min 11s, sys: 1.23 s, total: 1min 13s
# Wall time: 1min 13s

# %%
tr.show_recon();
tr.show_samples();

# %%
log_bias = tonp(tr.model.layer.log_bias.squeeze())
bias = np.exp(log_bias)
bias.shape
# Out:
# (128,)

# %%
fig, ax = create_figure(1, 1, (5, 2))
histplot(bias.ravel())
plt.show()

# %%
u0 = tonp(tr.model.layer.u_init[0].squeeze())
u0.shape
# Out:
# (128,)

# %%
histplot(u0.ravel())
plt.show()

# %%
print(sp_stats.pearsonr(u0.ravel(), log_bias.ravel()))
# Out:
# PearsonRResult(statistic=-0.46688184, pvalue=2.7735024032636617e-08)

# %%
# a = 'poisson_vH16-wht_t-8_b-4_k-128_m-8_<ngd|lin>'
# b = 'b200-ep300-lr(0.001)_temp(0.05)_gr(200)_ConvPhi:M=8_(2025_06_21,23:44)'
# tr, meta = load_model(pjoin(a, b), device)
# meta['checkpoint']
