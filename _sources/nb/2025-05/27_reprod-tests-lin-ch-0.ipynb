# %% [markdown]
# # (27) ICLR code + lin decoder
#
# **Motivation**: host = ```chewie```, device = ```cuda:0``` <br>

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-vae/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-vae/figs')
tmp_dir = os.path.join(git_dir, 'jb-vae/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_iclr_ipvae'))
from main.config_defaults import default_configs
from figures.convergence import plot_convergence
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: chewie

# %% [markdown]
# ## ICLR code: Poisson + vH16

# %%
model_type = 'poisson'
cfg_vae, cfg_tr = default_configs('vH16-wht', model_type, 'ngd|lin')

t_train = 10

cfg_vae['t_train'] = t_train
cfg_vae['kl_beta'] = 8/8 * t_train

cfg_vae['track_stats'] = True

# %% [markdown]
# ### Make model + trainer

# %%
model = MODEL_CLASSES[model_type](CFG_CLASSES[model_type](**cfg_vae))
tr = Trainer(model, ConfigTrain(**cfg_tr), device=device)

tr.n_iters
# Out:
# 154500

# %% [markdown]
# ### Print info

# %%
model.print()
tr.print()
tr.show_schedules()
# Out:
# +-------------+------------+
# | Module Name | Num Params |
# +-------------+------------+
# |    IPVAE    |  132.1 K   |
# |     ———     |    ———     |
# |    layer    |  132.1 K   |
# +-------------+------------+
# poisson_vH16-wht_t-10_b-10_k-512_<ngd|lin>
# b200-ep300-lr(0.001)_temp(0.05:0.5)_gr(200)_(2025_05_28,17:54)

# %%
model.layer.n_exp
# Out:
# tensor([50, 50, 50, 50, 50, 50, 50, 50, 50, 50], device='cuda:0',
#        dtype=torch.int32)

# %%
model.cfg.track_stats
# Out:
# True

# %%
print(f"{vars(tr.model.cfg)}\n\n\n{vars(tr.cfg)}")
# Out:
# {'prior_log_dist': 'uniform', 'clamp_prior': -4, 't_train': 10, 'kl_beta': 10.0, 'n_latents': 512, 'enc_type':
# 'ngd', 'dec_type': 'lin', 'recon_mode': 'mse', 'dataset': 'vH16-wht', 'dataset_name': 'vH16-wht', 'feeder':
# 'stationary', 'feeder_cfg': {}, 'input_sz': (1, 16, 16), 'shape': (-1, 1, 16, 16), 'init_dist': 'normal',
# 'init_scale': 0.0001, 'clamp_vals': {'u': (7.0,), 'du': (5.0,), 'dec': 3.45}, 'stochastic': True, 'fit_dec_var':
# False, 'fit_prior': True, 'seed': 0, 'track_stats': True, 'base_dir': '/home/hadi/Projects/PoissonVAE', 'data_dir':
# '/home/hadi/Datasets', 'runs_dir':
# '/home/hadi/Projects/PoissonVAE/runs/poisson_vH16-wht_t-10_b-10_k-512_<ngd|lin>', 'mods_dir':
# '/home/hadi/Projects/PoissonVAE/models/poisson_vH16-wht_t-10_b-10_k-512_<ngd|lin>', 'results_dir':
# '/home/hadi/Projects/PoissonVAE/results'}
#
#
# {'lr': 0.001, 'epochs': 300, 'batch_size': 200, 'dataset_kws': None, 'warm_restart': 0, 'warmup_portion': 0.005,
# 'optimizer': 'adamax_fast', 'optimizer_kws': {'weight_decay': 0.0, 'betas': (0.9, 0.999), 'eps': 1e-08},
# 'scheduler_type': 'cosine', 'scheduler_kws': {'T_max': 298.5, 'eta_min': 1e-05}, 'ema_rate': None, 'grad_clip':
# 200, 'chkpt_freq': 50, 'eval_freq': 20, 'log_freq': 10, 'method': 'mc', 'kl_beta_min': 0.0001, 'kl_const_portion':
# 0.001, 'kl_anneal_portion': 0.1, 'temp_anneal_portion': 0.5, 'temp_anneal_type': 'lin', 'temp_start': 1.0,
# 'temp_stop': 0.05}

# %%
print(tr.model.cfg.clamp_vals)
# Out:
# {'u': (7.0,), 'du': (5.0,), 'dec': 3.45}

# %% [markdown]
# ### Fit model

# %%
tr.train('Phase8:clamps_u=7.0_du=5.0+Lin')
# Out:
# Syncing run <strong><a href='https://wandb.ai/yateslab/_iclr_ipvae/runs/gc5njoem' target="_blank">poisson_vH16-wht_t-10_b-10_k-512_<ngd|lin>/b200-ep300-lr(0.001)_temp(0.05:0.5)_gr(200)_Phase8:clamps_u=7.0_du=5.0+Lin_(2025_05_28,17:54)</a></strong> <br>
#  View run at <a href='https://wandb.ai/yateslab/_iclr_ipvae/runs/gc5njoem' target="_blank">https://wandb.ai/yateslab/_iclr_ipvae/runs/gc5njoem</a>
# Warning: Could not save code info: Reference at 'refs/heads/main' does not exist
# epoch # 300, avg loss: 142.152: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [1:00:20<00:00, 12.07s/it]
#  View run <strong style="color:#cdcd00">poisson_vH16-wht_t-10_b-10_k-512_<ngd|lin>/b200-ep300-lr(0.001)_temp(0.05:0.5)_gr(200)_Phase8:clamps_u=7.0_du=5.0+Lin_(2025_05_28,17:54)</strong> at: <a href='https://wandb.ai/yateslab/_iclr_ipvae/runs/gc5njoem' target="_blank">https://wandb.ai/yateslab/_iclr_ipvae/runs/gc5njoem</a><br> View project at: <a href='https://wandb.ai/yateslab/_iclr_ipvae' target="_blank">https://wandb.ai/yateslab/_iclr_ipvae</a><br>Synced 4 W&B file(s), 12 media file(s), 0 artifact file(s) and 39 other file(s)

# %% [markdown]
# **Task:** reproduce this while gradually updating the code
#
# **Conclusion:**

# %%
# a = 'poisson_vH16-wht_t-10_b-10_k-512_<ngd|lin>'
# b = 'b200-ep300-lr(0.001)_temp(0.05:0.5)_gr(200)_Phase7Test:tuple+Lin_(2025_05_27,19:56)'
# tr, meta = load_model_main(a, b, device=device)
# meta['checkpoint']

# %%
print(tr.model.layer.n_exp)
# Out:
# tensor([14, 28, 50, 67, 72, 73, 73, 72, 73, 72], device='cuda:0',
#        dtype=torch.int32)

# %%
u_max = np.array(tr.model.stats['u_max'])
du_max = np.array(tr.model.stats['du_max'])

fig, ax = create_figure()
ax.plot(u_max, color='k', label='u', lw=0.2)
ax.plot(du_max, color='r', label='du', alpha=0.7, lw=0.2)
ax.legend()
plt.show()

# %%
max(tr.model.stats['du_max']), np.quantile(tr.model.stats['du_max'], 0.999)
# Out:
# (4.75985050201416, 3.363843488693234)

# %%
max(tr.model.stats['u_max']), np.quantile(tr.model.stats['u_max'], 0.999)
# Out:
# (5.135890483856201, 4.403126881599415)

# %%
# %%time

kws = dict(
    t_total=1000,
    n_data_batches=10,
    compute_sprs=True,
)
results = tr.analysis(dl='vld', **kws)
_ = plot_convergence(results, color='C0')
# Out:
# 100%|█████████████████████████████████| 10/10 [00:20<00:00,  2.01s/it]
# CPU times: user 27.1 s, sys: 728 ms, total: 27.8 s
# Wall time: 27.8 s

# %%
w = tr.model.layer.get_weight()
norms = tonp(torch.linalg.vector_norm(w, dim=1))
tr.model.show(order=np.argsort(norms), dpi=400, pad=1);

# %%
log_rate = tonp(tr.model.layer.u_init[0].squeeze())
bias = tonp(tr.model.layer.log_bias.exp().squeeze())

fig, axes = create_figure(1, 2, (10, 2))
kws = dict(fill=True, lw=3, alpha=0.3, ax=axes[0])
sns.histplot(log_rate, color='C0', element='step', label=r'$\log r$', **kws)

kws = dict(fill=True, lw=3, alpha=0.3, ax=axes[1])
sns.histplot(np.exp(log_rate), color='C0', element='step', label='rate', **kws)
sns.histplot(bias, color='C8', element='step', label='bias', **kws)

axes[1].set(ylabel='')
add_legend(axes)

plt.show()

# %%
dead = (log_rate < -1) | (log_rate > 2)
dead.sum(), (~dead).sum(), dead.sum() / len(dead)
# Out:
# (0, 512, 0.0)

# %%
histplot(bias, color='C8', lw=3)
plt.show()

# %%
(bias > 0).mean()
# Out:
# 1.0

# %%
bias[dead]
# Out:
# array([], dtype=float32)

# %%
mult = 1

results = tr.xtract_ftr(
    t_total=tr.model.cfg.t_train * mult,
    save_freq=mult,
    n_data_batches=10,
    data_batch_sz=2000,
    verbose=False,
)


fig, ax = create_figure(1, 1, (9, 3.5))
pal = get_cubehelix_palette(len(results['times']), start=2.5)

for i, t in enumerate(results['times']):
    sns.histplot(
        results['state_0'][:, i].ravel(),
        stat='percent',
        element='step',
        fill=False,
        color=pal[i],
        label=f"T = {t}",
        ax=ax,
    )
ax.legend(loc='upper left')
ax.grid()
plt.show()


fig, axes = create_figure(2, 1, (8, 5.8), sharex='col')
for i, t in enumerate(results['times']):
    for ax in axes.flat:
        sns.histplot(
            np.exp(results['state_0'][:, i].ravel()),
            stat='percent',
            element='step',
            fill=False,
            color=pal[i],
            label=f"T = {t}",
            ax=ax,
        )
axes[0].legend()
axes[1].set(yscale='log')
add_grid(axes)
plt.show()

# %%
pal
# Out:
# [[0.8975507056831679, 0.8094812603307622, 0.9465577040964425],
#  [0.8178323483750889, 0.7228373334284097, 0.9156857084467959],
#  [0.7243842279061081, 0.6447757533596252, 0.8762257510361532],
#  [0.621433610824204, 0.5738491579616475, 0.8244120665462615],
#  [0.5137602016853071, 0.5080741960907603, 0.7578471038208457],
#  [0.41165859076399486, 0.44819771588937396, 0.6800995692970601],
#  [0.3090934491249027, 0.3854178083786437, 0.5835384610223103],
#  [0.2159918198929715, 0.32026582325789205, 0.4738907509899629],
#  [0.13614552585465997, 0.2501791993868458, 0.35455980691569594],
#  [0.07235872150128392, 0.17287618251766537, 0.23013648857700542]]

# %%
grad = np.array(list(tr.stats['grad'].values()))

fig, axes = create_figure(1, 2)
axes[0].plot(np.log(grad))
axes[1].plot(np.log(grad)[:300])
plt.show()

# %%
(grad > 100).sum()
# Out:
# 0

# %%
# %%time

kws = dict(
    t_total=1000,
    n_data_batches=50,
    compute_sprs=False,
)
results = tr.analysis('vld', **kws)
_ = plot_convergence(results, color='k')
# Out:
# 100%|█████████████████████████████████| 50/50 [01:40<00:00,  2.01s/it]
# CPU times: user 2min 7s, sys: 3.6 s, total: 2min 11s
# Wall time: 2min 11s
