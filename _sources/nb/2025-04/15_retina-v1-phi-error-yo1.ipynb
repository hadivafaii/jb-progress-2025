# %% [markdown]
# # (15) Retina+V1: hack
#
# host: ```yoru```, device: ```cuda:1```
#
# **motivation:** <br>
#
# Kyoto16-bw
#
# Now apply phi before sending errors upward

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-25/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-25/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-25/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_RetinaV1'))
from figures.convergence import  plot_convergence
from figures.imgs import plot_weights
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
from main.config import Config


device_idx = 1
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:1  ———  host: yoru

# %%
cfg_layers = [
    CFG_CLASSES['gaus'](n_latents=128, beta_outer=64.0, latent_act='gompertz'),
    CFG_CLASSES['pois'](n_latents=512, beta_outer=12.0),
]
cfg = Config(
    dataset='Kyoto16-bw',
    cfg_layers=cfg_layers,
    t_train=16,
    n_iters_warmup=20,
)

# %%
tr = Trainer(
    model=RetinaV1(cfg),
    cfg=ConfigTrain(epochs=800),
    device=device,
)
tr.n_iters
# Out:
# 156800

# %%
print(tr.model)
# Out:
# RetinaV1(
#   (layers): ModuleDict(
#     (g0): GaussianGompertzLayer(input_dim=256, latent_dim=128, temperature=1, beta_inner=1, eps=1)
#     (p1): PoissonLayer(input_dim=128, latent_dim=512, temperature=1, beta_inner=1, eps=1)
#   )
# )

# %%
tr.print()
# Out:
# Kyoto16-bw_m(g0+gomp,p1)_t(20+16)_b(64,12)_k(128,512)
# b200-ep800-lr(0.002)_temp(0.01:0.5)_gr(500)_(2025_04_15,16:38)

# %%
cm = 'phi@error'
tr.train(fit_name=f"{cm}_{tr.cfg.name()}")

# tr.train()
# Out:
# epoch # 100, avg loss: -86.354:  12%|▌    | 99/800 [1:43:43<12:14:25, 62.86s/it]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 cm = 'phi@error'
# ----> 2 tr.train(fit_name=f"{cm}_{tr.cfg.name()}")
#
# File ~/Dropbox/git/_RetinaV1/base/train_base.py:109, in BaseTrainer.train(self, fit_name, epochs, fresh_fit, save)
#     107 	if (epoch + 1) % self.cfg.eval_freq == 0:
#     108 		gstep = (epoch + 1) * len(self.dl_trn)
# --> 109 		self.validate(gstep)
#     110 if self.writer is not None:
#     111 	self.writer.close()
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_RetinaV1/main/train.py:458, in Trainer.validate(self, gstep, n_samples, **kwargs)
#     455 		self.stats[k][gstep] = v
#     457 	# add figs
# --> 458 	self.figs_to_writer(gstep)
#     460 return loss, samples
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_RetinaV1/main/train.py:860, in Trainer.figs_to_writer(self, gstep)
#     857 for i, (name, layer) in enumerate(
#     858 		self.model.layers.items()):
#     859 	n = self.model.cfg.n_latents[i]
# --> 860 	figs[name] = self.model.show(
#     861 		which=name,
#     862 		method=method,
#     863 		order=np.argsort(tonp(
#     864 			layer.u_init[0].squeeze())),
#     865 		nrows=int(np.ceil(n / div)),
#     866 		add_title=False,
#     867 		display=False,
#     868 		dpi=dpi,
#     869 	)[0]
#     870 for name, f in figs.items():
#     871 	self.writer.add_figure(f'figs/{name}', f, gstep)
#
# File ~/Dropbox/git/_RetinaV1/main/model.py:162, in show(self, which, order, method, add_title, display, **kwargs)
#     160 w = w.T.reshape(self.cfg.shape)
#     161 w = tonp(w.squeeze())
# --> 162 if order is not None:
#     163 	w = w[order]
#     165 pad = 0 if self.cfg.input_sz[0] == 3 else 1
#
# IndexError: index 500 is out of bounds for axis 0 with size 256

# %%
w_retina = tr.model.layers['g0'].get_weight().T
w_v1 = tr.model.layers['p1'].get_weight().T

w_retina.shape, w_v1.shape
# Out:
# (torch.Size([128, 256]), torch.Size([512, 128]))

# %%
w = w_v1 @ w_retina
w.shape
# Out:
# torch.Size([512, 256])

# %%
plot_weights(w.reshape(-1, 16, 16))
# Out:
# (<Figure size 1280x640 with 1 Axes>, <Axes: >)

# %%
from analysis.sta import perform_sta_analysis
from utils.animation import show_movie

# %%
sta = perform_sta_analysis(tr, batch_size=1_000)
# Out:
# 100%|█████████████████████████████████████████| 100/100 [05:45<00:00,  3.46s/it]

# %%
n_lags = 80
s_kers = {
    name: np_nans((len(sta_array), 16, 16))
    for name, sta_array in sta.items()
}
t_kers = {
    name: np_nans((len(sta_array), n_lags + 1))
    for name, sta_array in sta.items()
}

for name, sta_array in sta.items():
    for i in range(len(sta_array)):
        uu, ss, vvh = torch.linalg.svd(
            sta_array[i], full_matrices=False)
    
        s_kers[name][i] = tonp(vvh[0]).reshape(16, 16)
        t_kers[name][i] = tonp(uu[:, 0])

# %%
name = 'g0'
i, j = 57, 25
vminmax = np.abs(s_kers[name][[i, j]]).max()

fig, axes = create_figure(1, 3, (7.3, 2.0), width_ratios=[1, 1, 1.7])

im = axes[0].imshow(s_kers[name][i], cmap='Greys_r', vmin=-vminmax, vmax=vminmax)
im = axes[1].imshow(s_kers[name][j], cmap='Greys_r', vmin=-vminmax, vmax=vminmax)
plt.colorbar(im, ax=axes[1])

axes[2].plot(t_kers[name][i], color='k')
axes[2].plot(t_kers[name][j], color='C0')
axes[2].grid()

remove_ticks(axes[:2], False)
plt.show()

# %%
name = 'p1'
i, j = 59, 29
vminmax = np.abs(s_kers[name][[i, j]]).max()

fig, axes = create_figure(1, 3, (7.3, 2.0), width_ratios=[1, 1, 1.7])

im = axes[0].imshow(s_kers[name][i], cmap='Greys_r', vmin=-vminmax, vmax=vminmax)
im = axes[1].imshow(s_kers[name][j], cmap='Greys_r', vmin=-vminmax, vmax=vminmax)
plt.colorbar(im, ax=axes[1])

axes[2].plot(t_kers[name][i], color='k')
axes[2].plot(t_kers[name][j], color='C0')
axes[2].grid()

remove_ticks(axes[:2], False)
plt.show()

# %%
u0 = {
    k: tonp(layer.u_init[0].squeeze()) for
    k, layer in tr.model.layers.items()
}
for k, v in u0.items():
    kws = dict(
        order=np.argsort(v),
        nrows=16 if k == 'p1' else 4,
        method='abs-max',
    )
    tr.model.show(k, **kws);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 11
#       5 for k, v in u0.items():
#       6     kws = dict(
#       7         order=np.argsort(v),
#       8         nrows=16 if k == 'p1' else 4,
#       9         method='abs-max',
#      10     )
# ---> 11     tr.model.show(k, **kws)
#
# File ~/Dropbox/git/_RetinaV1/main/model.py:162, in show(self, which, order, method, add_title, display, **kwargs)
#     160 w = w.T.reshape(self.cfg.shape)
#     161 w = tonp(w.squeeze())
# --> 162 if order is not None:
#     163 	w = w[order]
#     165 pad = 0 if self.cfg.input_sz[0] == 3 else 1
#
# IndexError: index 500 is out of bounds for axis 0 with size 256

# %%
## Was: t_warmup = 32

# %%
var = {}
for name, layer in tr.model.layers.items():
    log_sigma = layer.get_dec_log_sigma()
    var[name] = tonp(torch.exp(log_sigma ** 2).squeeze()).reshape(16, 16)

# %%
fig, axes = create_figure(1, 2)
im = axes[0].imshow(var['g0'], cmap='Greys_r')
plt.colorbar(im, ax=axes[0])

im = axes[1].imshow(var['p1'], cmap='Greys_r')
plt.colorbar(im, ax=axes[1])

plt.show()

# %%
fig, axes = create_figure(1, 2)

sns.kdeplot(tonp(tr.model.layers['g0'].get_weight().ravel()), color='C0', label='Retina', ax=axes[0])
sns.kdeplot(tonp(tr.model.layers['p1'].get_weight().ravel()), color='C1', label='V1', ax=axes[1])

add_legend(axes)
plt.show()

# %%
tr.cfg.batch_size = 3000
tr.setup_data()

# %%
# %%time


items = ['mse', 'r2', 'u', 'samples']

t_total = 1000

r2 = {k: np_nans(t_total) for k in tr.model.layers}
mse = {k: np_nans(t_total) for k in tr.model.layers}

true = []
pred = collections.defaultdict(list)
error = collections.defaultdict(list)

state = collections.defaultdict(list)
samples = collections.defaultdict(list)

for x, *_ in tqdm(iter(tr.dl_vld)):
    feeder = tr.get_feeder(x)
    for t in range(t_total):
        tr.model.update_time(t)
        inpt = feeder[t]
        output = tr.model.xtract_ftr(inpt, return_extras=items)
        for k, d in output.items():
            r2[k][t] = d['r2'].mean(0).item()
            mse[k][t] = d['mse'].mean(0).item()

        if (t + 1) == t_total:
            true.append(inpt.flatten(start_dim=1))
            for k, layer in tr.model.layers.items():
                pred[k].append(layer.conditional.loc)
                state[k].append(output[k]['u'])
                samples[k].append(output[k]['samples'])
            pred_error_retina = tr.model.layers['g0'].phi(tr.model.layers['g0'].pred_error(
                x=inpt, weighted=False), transpose=True)
            error['g0'].append(pred_error_retina)
            error['p1'].append(tr.model.layers['p1'].phi(tr.model.layers['p1'].pred_error(
                x=pred_error_retina, weighted=False), transpose=True))

del output
torch.cuda.empty_cache()
import gc
gc.collect()

true = torch.cat(true)
pred = {k: torch.cat(v) for k, v in pred.items()}
error = {k: torch.cat(v) for k, v in error.items()}
state = {k: torch.cat(v) for k, v in state.items()}
samples = {k: torch.cat(v) for k, v in samples.items()}
# Out:
# 100%|█████████████████████████████████████████████| 4/4 [00:32<00:00,  8.07s/it]
# CPU times: user 32.5 s, sys: 177 ms, total: 32.7 s
# Wall time: 32.7 s

# %%
fig, axes = create_figure(2, 2, sharex='all')
axes[0, 0].plot(mse['g0'])
axes[0, 1].plot(mse['p1'])
axes[1, 0].plot(r2['g0'])
axes[1, 1].plot(r2['p1'])

axes[0, 0].set(yscale='log')
axes[0, 1].set(yscale='log')
# axes[-1, -1].set(xscale='log')
plt.show()

# %%
fig, axes = create_figure(2, 2, sharex='all')

intvl = range(32)

axes[0, 0].plot(mse['g0'][intvl], marker='.', label='mse — retina')
axes[0, 1].plot(mse['p1'][intvl], marker='.', color='C1', label='mse — v1')
axes[1, 0].plot(r2['g0'][intvl], marker='.', label='r2 — retina')
axes[1, 1].plot(r2['p1'][intvl], marker='.', color='C1', label='r2 — v1')

add_legend(axes)
add_grid(axes)
# axes[-1, -1].set(xscale='log')
plt.show()

# %%
r2['p1'][-10:]
# Out:
# array([0.22063364, 0.23067774, 0.23026796, 0.22344084, 0.22548169,
#        0.22013612, 0.21666196, 0.21553251, 0.23196252, 0.22213802])

# %%
# order: high contrast
var = tonp(torch.var(true, dim=1))
order = np.argsort(var)[::-1]

# get whitened data
_, whitened, _ = make_dataset('Kyoto16-wht', device)
whitened = whitened.tensors[0].flatten(start_dim=1)
whitened.shape
# Out:
# torch.Size([9821, 256])

# %%
def _plot_selected_samples(select_from=None, ncols=20, seed=0):
    rng = get_rng(seed)

    nrows = 6
    fig, axes = create_figure(nrows, ncols, (1 * ncols + 0.1, 1 * nrows), 'all', 'all')

    select_from = order[:200] if select_from is None else select_from
    selected_ids = rng.choice(select_from, size=ncols, replace=False)

    for i in range(ncols):
        idx = selected_ids[i]
        axes[0, i].imshow(tonp(true[idx]).reshape(16, 16), cmap='Greys_r')
        axes[1, i].imshow(tonp(pred['g0'][idx]).reshape(16, 16), cmap='Greys_r')
        axes[2, i].imshow(tonp(error['g0'][idx]).reshape(8, 16), cmap='Greys_r')
        axes[3, i].imshow(tonp(whitened[idx]).reshape(16, 16), cmap='Greys_r')
        axes[4, i].imshow(tonp(pred['p1'][idx]).reshape(8, 16), cmap='Greys_r')
        axes[5, i].imshow(tonp(error['p1'][idx]).reshape(32, 16), cmap='Greys_r')
    
    axes[0, 0].set_ylabel('img', fontsize=15)
    axes[1, 0].set_ylabel('pred\n(retina)', fontsize=15)
    axes[2, 0].set_ylabel('error\n(retina)', fontsize=15)
    axes[3, 0].set_ylabel('whitened', fontsize=15)
    axes[4, 0].set_ylabel('pred\n(v1)', fontsize=15)
    axes[5, 0].set_ylabel('error\n(v1)', fontsize=15)

    remove_ticks(axes, False)
    plt.show()

# %%
_plot_selected_samples()

# %%
fig, axes = create_figure(2, 2, sharex='col', sharey='row')
sns.histplot(tonp(error['g0'].ravel()), stat='percent', color='C4', label='PHI error\n(retina)', ax=axes[0, 0])
# sns.histplot(tonp(phi_error['g0'].ravel()), stat='percent', color='C4', label='phi^T @ error\n(retina)', ax=axes[0, 1])
sns.histplot(tonp(error['p1'].ravel()), stat='percent', color='C5', label='PHI error\n(v1)', ax=axes[1, 0])
# sns.histplot(tonp(phi_error['p1'].ravel()), stat='percent', color='C5', label='phi^T @ error\n(v1)', ax=axes[1, 1])
add_legend(axes)
plt.show()
