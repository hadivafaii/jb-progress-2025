# %% [markdown]
# # Jobs: rate-dist refit gaussian + relu
#
# project = ```iP-VAE```, host = ```yoru```, device = ```any```
#
# **Motivation**: <br>
#
# Refit gaussian+relu

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_IterativeVAE'))
from figures.convergence import plot_convergence
from figures.imgs import plot_weights
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %% [markdown]
# ## Setup

# %%
from base.helper import job_runner_script


def _cleanup(path, host=None):
    for f in os.listdir(path):
        cond = f.endswith('.txt')
        if host is not None:
            cond = cond and host in f
        if cond:
            os.remove(pjoin(path, f))


def _name(host, gpu_i, fit_i):
    return f"{host}-cuda{gpu_i}-fit{fit_i}"

# %%
save_dir = 'Dropbox/git/_IterativeVAE/scripts'
save_dir = pjoin(os.environ['HOME'], save_dir)
os.makedirs(save_dir, exist_ok=True)

# delete existing job runners?
_cleanup(save_dir, None)

print(sorted(os.listdir(save_dir)))
# Out:
# [
#     'cleanup_chkpts.sh',
#     'cleanup_recursive.sh',
#     'copyfits.sh',
#     'fit_model.sh',
#     'kill_screens.sh',
#     'resume_fit.sh',
#     'run_sessions.sh',
#     'test_tqdm.py',
#     'test_tqdm.sh'
# ]

# %% [markdown]
# ## Betas

# %%
host = 'mach'
_cleanup(save_dir, host)

scripts = collections.defaultdict(list)
tot = 0

# %%
latent_act = 'relu'
model_type = 'gaussian'

t_b_combos = {
    8: [1, 2, 4, 8, 12, 16, 20, 24, 32],
    16: [1, 2, 4, 8, 12, 16, 20, 24, 32, 48, 64],
    32: [1, 2, 4, 8, 12, 16, 20, 24, 32, 48, 64, 96],
}

# %%
for t_train, beta_list in t_b_combos.items():   
    for beta in beta_list:
        arg = ' '.join([
            f"--t_train {t_train}",
            f"--beta_outer {beta}",
            f"--latent_act '{latent_act}'",
            '--comment relufix',
        ])
        gpu_i = tot % 4
        kws = dict(
            device=gpu_i,
            dataset='vH16-wht',
            model=model_type,
            args=arg,
            seed=665,
        )
        scripts[gpu_i].append(job_runner_script(**kws))
        tot += 1

# %%
print(tot)
# Out:
# 32

# %%
scripts = dict(scripts)
print({k: len(v) for k, v in scripts.items()})
# Out:
# {0: 8, 1: 8, 2: 8, 3: 8}

# %% [markdown]
# ### Save

# %%
n_fits = 4

for gpu_i, scripts in scripts.items():
    scripts_divided = divide_list(scripts, n_fits)
    for fit_i, s in enumerate(scripts_divided):
        combined = ' && '.join(s)
        save_obj(
            obj=combined,
            file_name=_name(host, gpu_i, fit_i),
            save_dir=save_dir,
            mode='txt',
        )
        print(combined.replace('&& ', '&& \n'))
# Out:
# [PROGRESS] 'mach-cuda0-fit0.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '0' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 1 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '0' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 12 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda0-fit1.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '0' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 32 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '0' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 8 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda0-fit2.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '0' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 24 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '0' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 1 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda0-fit3.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '0' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 12 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '0' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 32 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda1-fit0.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '1' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 2 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '1' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 16 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda1-fit1.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '1' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 1 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '1' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 12 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda1-fit2.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '1' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 32 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '1' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 2 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda1-fit3.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '1' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 16 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '1' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 48 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda2-fit0.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '2' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 4 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '2' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 20 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda2-fit1.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '2' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 2 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '2' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 16 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda2-fit2.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '2' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 48 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '2' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 4 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda2-fit3.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '2' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 20 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '2' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 64 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda3-fit0.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 8 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 24 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda3-fit1.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 4 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 20 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda3-fit2.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 64 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 8 --latent_act 'relu' --comment
# relufix
# [PROGRESS] 'mach-cuda3-fit3.txt' saved at
# /home/hadi/Dropbox/git/_IterativeVAE/scripts
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 24 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 96 --latent_act 'relu' --comment
# relufix

# %% [markdown]
# Print one to check

# %%
print(combined.replace('&& ', '&& \n'))
# Out:
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 24 --latent_act 'relu' --comment
# relufix &&
# ./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 96 --latent_act 'relu' --comment
# relufix

# %%
print(scripts)
# Out:
# [
#     "./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 8 --latent_act 'relu' --comment
# relufix",
#     "./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 8 --beta_outer 24 --latent_act 'relu' --comment
# relufix",
#     "./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 4 --latent_act 'relu' --comment
# relufix",
#     "./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 20 --latent_act 'relu' --comment
# relufix",
#     "./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 16 --beta_outer 64 --latent_act 'relu' --comment
# relufix",
#     "./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 8 --latent_act 'relu' --comment
# relufix",
#     "./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 24 --latent_act 'relu' --comment
# relufix",
#     "./fit_model.sh '3' 'vH16-wht' 'gaussian' --seed 665 --t_train 32 --beta_outer 96 --latent_act 'relu' --comment
# relufix"
# ]
