# %% [markdown]
# # process fits, save results (iterative)
#
# host = ```yoru```, device = ```cuda:0```
#
# **Motivation**: <br>
#
# From ```Dropbox/chkpts/_IterativeVAE``` to ```../tmp/results_apr2025```

# %%
# HIDE CODE


import os, sys
from IPython.display import display

# tmp & extras dir
git_dir = os.path.join(os.environ['HOME'], 'Dropbox/git')
extras_dir = os.path.join(git_dir, 'jb-progress-2025/_extras')
fig_base_dir = os.path.join(git_dir, 'jb-progress-2025/figs')
tmp_dir = os.path.join(git_dir, 'jb-progress-2025/tmp')

# GitHub
sys.path.insert(0, os.path.join(git_dir, '_IterativeVAE'))
from figures.convergence import plot_convergence
from figures.imgs import plot_weights
from figures.fighelper import *
from main.train import *

# warnings, tqdm, & style
warnings.filterwarnings('ignore', category=DeprecationWarning)
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
from rich.jupyter import print
# %matplotlib inline
set_style()

# %%
from analysis.final import perform_analysis, get_root_path


device_idx = 0
device = f'cuda:{device_idx}'

print(f"device: {device}  ———  host: {os.uname().nodename}")
# Out:
# device: cuda:0  ———  host: yoru

# %% [markdown]
# ## Results dir

# %%
root = get_root_path()
results_dir = pjoin(tmp_dir, 'results_2025-04')
os.makedirs(results_dir, exist_ok=True)

len(os.listdir(results_dir))
# Out:
# 2

# %% [markdown]
# ## Run analysis loop

# %%
fits = [f for f in sorted(os.listdir(root)) if '2025_04_11' in f]
print(fits)
# Out:
# [
#     'gaussian+softplus_<grad|lin>_vH16-bw_t-16_b-16_k-[512]_yoru-0_(2025_04_11,17:36)',
#     'poisson_<grad|lin>_Kyoto16-wht_t-16_b-24_k-[512]_yoru-0_(2025_04_11,16:59)',
#     'poisson_<grad|lin>_vH16-wht_t-16_b-24_k-[512]_yoru-0_(2025_04_11,16:58)'
# ]

# %%
# %%time

perform_analysis(results_dir, device, fits)
# Out:
#   0%|                                                     | 0/3 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <timed eval>:1
#
# File ~/Dropbox/git/_IterativeVAE/analysis/final.py:83, in perform_analysis(results_dir, device, fits, kws_analysis, kws_untangle, attrs, attrs_tr, override_fits, verbose)
#      81 # (3) dataset-specific analyses
#      82 if tr.model.cfg.dataset.startswith(('vH', 'Kyoto')):
# ---> 83 	results = tr.analysis(**kws_analysis)
#      84 	# get map estimate r2
#      85 	state = tr.to(results['state_final'])
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_IterativeVAE/main/train.py:710, in Trainer.analysis(self, dl, t_total, data_batch_sz, n_data_batches, active, return_recon, compute_sprs, avg_samples, verbose, **kwargs)
#     708 self.model.update_time(t)
#     709 # (2) fwd pass
# --> 710 output = model.xtract_ftr(feeder[t], **kwargs)
#     711 # (3) save
#     712 if (t + 1) == t_total:
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Dropbox/git/_IterativeVAE/main/model.py:43, in _IterativeVAE.xtract_ftr(self, x, **kwargs)
#      41 temp = self.cfg.validation_temp
#      42 kwargs.setdefault('temp', temp)
# ---> 43 return self.forward(x, **kwargs)
#
# File ~/Dropbox/git/_IterativeVAE/main/model.py:23, in _IterativeVAE.forward(self, x, temp, return_extras, override_input)
#      21 	x = self.pred  # → hallucinates
#      22 # (1) bottom-up pass
# ---> 23 _ = self.layer(x, temp=temp)
#      24 # (2) generate & update:
#      25 self.update_generation_state(temp=temp)
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:36, in _StochasticLayer.forward(self, x, temp)
#      34 	return self.infer(x)
#      35 with self.temporary_temperature(temp):
# ---> 36 	return self.infer(x)
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:40, in _StochasticLayer.infer(self, x)
#      38 def infer(self, x):
#      39 	if self._cfg.inf_type == 'grad':
# ---> 40 		return self.infer_grad(x)
#      41 	elif self._cfg.inf_type == 'leapfrog':
#      42 		return self.infer_leapfrog(x)
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:51, in _StochasticLayer.infer_grad(self, x)
#      49 for n in range(self._cfg.n_iters_inner):
#      50 	self.n_updates += 1
# ---> 51 	grad_f = self.grad_free_energy(x)
#      52 	u_dot = tuple(
#      53 		llr.exp() * g.mul(-1.0) for g, llr
#      54 		in zip(grad_f, self.log_lr)
#      55 	)
#      56 	u_dot = tuple(
#      57 		self.softclamp(item, 'du', i)
#      58 		for i, item in enumerate(u_dot)
#      59 	)
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:486, in GaussianLayer.grad_free_energy(self, x)
#     484 def grad_free_energy(self, x):
#     485 	# (1) recon
# --> 486 	grad_recon = self.grad_recon_term(x)
#     487 	eps = self.posterior.retrieve_noise(self.samples)
#     488 	# (2) kl
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:82, in _StochasticLayer.grad_recon_term(self, x)
#      80 self.update_inference_state()
#      81 # (2) apply activation fun
# ---> 82 z = self.apply_act_fn()
#      83 # (3) decoder variance
#      84 dec_log_sigma = self.get_dec_log_sigma()
#
# File ~/Dropbox/git/_IterativeVAE/main/layers.py:156, in _StochasticLayer.apply_act_fn(self, z)
#     154 	z = self.samples
#     155 if self.activation is not None:
# --> 156 	return self.activation(z)
#     157 return z
#
# File ~/Dropbox/git/_IterativeVAE/main/activations.py:127, in Softplus.__init__(self, n_latents, beta_init, **kwargs)
#     121 def __init__(
#     122 		self,
#     123 		n_latents: int,
#     124 		beta_init: float = 1.0,  # smoothing parameter
#     125 		**kwargs,
#     126 ):
# --> 127 	super(Softplus, self).__init__(
#     128 		n_latents, **kwargs)
#     129 	# beta: controls the smoothness of the curve
#     130 	self.log_beta = nn.Parameter(
#     131 		data=torch.ones(1, n_latents) * np.log(beta_init),
#     132 		requires_grad=self.fit_params,
#     133 	)
#
# File ~/Dropbox/git/_IterativeVAE/main/activations.py:15, in Activation.__init__(self, n_latents, fit_params)
#      12 self.fit_params = fit_params
#      13 # output gain
#      14 self.log_gain = nn.Parameter(
# ---> 15 	data=torch.ones(1, n_latents),
#      16 	requires_grad=self.fit_params,
#      17 )
#
# TypeError: ones(): argument 'size' failed to unpack the object at pos 2 with error "type must be tuple of ints,but got Tensor"
